# %% [markdown]
# ## Collaborative filtering using Python

# %% [markdown]
# Alright, so let's do it! We have some Python code that will use Pandas, and all the various other tools at our disposal, to create movie recommendations with a surprisingly little amount of code.
#
# The first thing we're going to do is show you item-based collaborative filtering in practice. So, we'll build up *people who watched also watched* basically, you know, *people who rated things highly also rated this thing highly*, so building up these movie to movie relationships. So, we're going to base it on real data that we got from the MovieLens project. So, if you go to MovieLens.org, there's actually an open movie recommender system there, where people can rate movies and get recommendations for new movies.
#
# And, they make all the underlying data publicly available for researchers like us. So, we're going to use some real movie ratings data-it is a little bit dated, it's like 10 years old, so keep that in mind, but it is real behavior data that we're going to be working with finally here. And, we will use that to compute similarities between movies. And, that data in and of itself is useful. You can use that data to say *people who liked also liked*. So, let's say I'm looking at a web page for a movie. the system can then say: *if you liked this movie, and given that you're looking at it you're probably interested in it, then you might also like these movies*. And that's a form of a recommender system right there, even though we don't even know who you are.
#
# Now, it is real-world data, so we're going to encounter some real-world problems with it. Our initial set of results aren't going to look good, so we're going to spend a little bit of extra time trying to figure out why, which is a lot of what you spend your time doing as a data scientist-correct those problems, and go back and run it again until we get results that makes sense.
#
# And finally, we'll actually do item-based collaborative filtering in its entirety, where we actually recommend movies to individuals based on their own behavior. So, let's do this, let's get started!

# %% [markdown]
# ## Finding movie similarities

# %% [markdown]
# Let's apply the concept of item-based collaborative filtering. To start with, movie similarities-figure out what movies are similar to other movies. In particular, we'll try to figure out what movies are similar to Star Wars, based on user rating data, and we'll see what we get out of it. Let's dive in!
#
# Okay so, let's go ahead and compute the first half of item-based collaborative filtering, which is finding similarities between items.

# %%
import pandas as pd

r_cols = ['user_id','movie_id','rating']
ratings = pd.read_csv('u.data.csv',names=r_cols, usecols=range(3))
m_cols = ['movie_id','title']
movies = pd.read_csv('u.item.csv',names=m_cols, sep='|',usecols=range(2))
#print(ratings.head())
ratings = pd.merge(movies,ratings)
ratings.to_csv('ratings.csv')
movies.head()
# Out:
#    movie_id              title
# 0         1   Toy Story (1995)
# 1         2   GoldenEye (1995)
# 2         3  Four Rooms (1995)
# 3         4  Get Shorty (1995)
# 4         5     Copycat (1995)

# %% [markdown]
# In this case, we're going to be looking at similarities between movies, based on user behavior. And, we're going to be using some real movie rating data from the GroupLens project. GroupLens.org provides real movie ratings data, by real people who are using the MovieLens.org website to rate movies and get recommendations back for new movies that they want to watch.
#
# We have included the data files that you need from the GroupLens dataset with the course materials, and the first thing we need to do is import those into a Pandas DataFrame, and we're really going to see the full power of Pandas in this example. It's pretty cool stuff!

# %% [markdown]
# Let's add a `ratings.head()` command and then run those cells. What we end up with is something like the following table. That was pretty quick!

# %%
ratings.head()
# Out:
#    movie_id             title  user_id  rating
# 0         1  Toy Story (1995)      308       4
# 1         1  Toy Story (1995)      287       5
# 2         1  Toy Story (1995)      148       4
# 3         1  Toy Story (1995)      280       4
# 4         1  Toy Story (1995)       66       3

# %% [markdown]
# We end up with a new DataFrame that contains the `user_id` and rating for each movie that a user rated, and we have both the `movie_id` and the `title` that we can read and see what it really is. So, the way to read this is `user_id` number `308` rated the `Toy Story (1995)` movie 4 stars, `user_id` number `287` rated the `Toy Story (1995)` movie 5 stars, and so on and so forth. And, if we were to keep looking at more and more of this DataFrame, we'd see different ratings for different movies as we go through it.

# %% [markdown]
# Now the real magic of Pandas comes in. So, what we really want is to look at relationships between movies based on all the users that watched each pair of movies, so we need, at the end, a matrix of every movie, and every user, and all the ratings that every user gave to every movie. The `pivot_table` command in Pandas can do that for us. It can basically construct a new table from a given DataFrame, pretty much any way that you want it. For this, we can use the following code:

# %%
movieRatings = ratings.pivot_table(index=['user_id'],columns=['title'],values=['rating'])
movieRatings.head()
# Out:
#                            rating                                     \
# title   'Til There Was You (1997) 1-900 (1994) 101 Dalmatians (1996)
# user_id
# 0                             NaN          NaN                   NaN
# 1                             NaN          NaN                   2.0
# 2                             NaN          NaN                   NaN
# 3                             NaN          NaN                   NaN
# 4                             NaN          NaN                   NaN
#
#                                                                     \
# title   12 Angry Men (1957) 187 (1997) 2 Days in the Valley (1996)
# user_id
# 0                       NaN        NaN                         NaN
# 1                       5.0        NaN                         NaN
# 2                       NaN        NaN                         NaN
# 3                       NaN        2.0                         NaN
# 4                       NaN        NaN                         NaN
#
#                                                                           \
# title   20,000 Leagues Under the Sea (1954) 2001: A Space Odyssey (1968)
# user_id
# 0                                       NaN                          NaN
# 1                                       3.0                          4.0
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
#
#                                                                           ...  \
# title   3 Ninjas: High Noon At Mega Mountain (1998) 39 Steps, The (1935)  ...
# user_id                                                                   ...
# 0                                               NaN                  NaN  ...
# 1                                               NaN                  NaN  ...
# 2                                               1.0                  NaN  ...
# 3                                               NaN                  NaN  ...
# 4                                               NaN                  NaN  ...
#
#                                                                        \
# title   Wyatt Earp (1994) Yankee Zulu (1994) Year of the Horse (1997)
# user_id
# 0                     NaN                NaN                      NaN
# 1                     NaN                NaN                      NaN
# 2                     NaN                NaN                      NaN
# 3                     NaN                NaN                      NaN
# 4                     NaN                NaN                      NaN
#
#                                                                          \
# title   You So Crazy (1994) Young Frankenstein (1974) Young Guns (1988)
# user_id
# 0                       NaN                       NaN               NaN
# 1                       NaN                       5.0               3.0
# 2                       NaN                       NaN               NaN
# 3                       NaN                       NaN               NaN
# 4                       NaN                       NaN               NaN
#
#                                                                     \
# title   Young Guns II (1990) Young Poisoner's Handbook, The (1995)
# user_id
# 0                        NaN                                   NaN
# 1                        NaN                                   NaN
# 2                        NaN                                   NaN
# 3                        NaN                                   NaN
# 4                        NaN                                   NaN
#
#
# title   Zeus and Roxanne (1997) unknown
# user_id
# 0                           NaN     NaN
# 1                           NaN     4.0
# 2                           NaN     NaN
# 3                           NaN     NaN
# 4                           NaN     NaN
#
# [5 rows x 1664 columns]

# %% [markdown]
# It's kind of amazing how that just put it all together for us. Now, you'll see some NaN values, which stands for **Not a Number**, and its just how Pandas indicates a missing value. So, the way to interpret this is, `user_id` number 1, for example, did not watch the movie `1-900 (1994)`, but `user_id` number 1 did watch `101 Dalmatians (1996)` and rated it 2 stars. The `user_id` number 1 also watched `12 Angry Men (1957)` and rated it 5 stars, but did not watch the movie 2 Days in `the Valley (1996)`, for example, okay? So, what we end up with here is a sparse matrix basically, that contains every user, and every movie, and at every intersection where a user rated a movie there's a rating value.
#
# So, you can see now, we can very easily extract vectors of every movie that our user watched, and we can also extract vectors of every user that rated a given movie, which is what we want. So, that's useful for both user-based and item-based collaborative filtering, right? If I wanted to find relationships between users, I could look at correlations between these user rows, but if I want to find correlations between movies, for item-based collaborative filtering, I can look at correlations between columns based on the user behavior. So, this is where the real *flipping things on its head for user versus item-based similarities* comes into play.
#
# Now, we're going with item-based collaborative filtering, so we want to extract columns, to do this let's run the following code:

# %%
starWarsRatings = movieRatings['rating','Star Wars (1977)']
starWarsRatings.head()
# Out:
# user_id
# 0    5.0
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# Name: (rating, Star Wars (1977)), dtype: float64

# %% [markdown]
# Now, with the help of that, let's go ahead and extract all the users who rated Star Wars (1977):
#
# And, we can see most people have, in fact, watched and rated `Star Wars (1977)` and everyone liked it, at least in this little sample that we took from the head of the DataFrame. So, we end up with a resulting set of user IDs and their ratings for `Star Wars (1977)`. The user ID 3 did not rate `Star Wars (1977)` so we have a `NaN` value, indicating a missing value there, but that's okay. We want to make sure that we preserve those missing values so we can directly compare columns from different movies. So, how do we do that?

# %% [markdown]
# ## The corrwith function

# %%
corrMatrix = movieRatings.corr(method='pearson',min_periods=100)  #pearson is the corr method
corrMatrix.head()
# Out:
#                                                     rating               \
# title                            'Til There Was You (1997) 1-900 (1994)
#        title
# rating 'Til There Was You (1997)                       NaN          NaN
#        1-900 (1994)                                    NaN          NaN
#        101 Dalmatians (1996)                           NaN          NaN
#        12 Angry Men (1957)                             NaN          NaN
#        187 (1997)                                      NaN          NaN
#
#                                                                             \
# title                            101 Dalmatians (1996) 12 Angry Men (1957)
#        title
# rating 'Til There Was You (1997)                   NaN                 NaN
#        1-900 (1994)                                NaN                 NaN
#        101 Dalmatians (1996)                       1.0                 NaN
#        12 Angry Men (1957)                         NaN                 1.0
#        187 (1997)                                  NaN                 NaN
#
#                                                                          \
# title                            187 (1997) 2 Days in the Valley (1996)
#        title
# rating 'Til There Was You (1997)        NaN                         NaN
#        1-900 (1994)                     NaN                         NaN
#        101 Dalmatians (1996)            NaN                         NaN
#        12 Angry Men (1957)              NaN                         NaN
#        187 (1997)                       NaN                         NaN
#
#                                                                       \
# title                            20,000 Leagues Under the Sea (1954)
#        title
# rating 'Til There Was You (1997)                                 NaN
#        1-900 (1994)                                              NaN
#        101 Dalmatians (1996)                                     NaN
#        12 Angry Men (1957)                                       NaN
#        187 (1997)                                                NaN
#
#                                                                \
# title                            2001: A Space Odyssey (1968)
#        title
# rating 'Til There Was You (1997)                          NaN
#        1-900 (1994)                                       NaN
#        101 Dalmatians (1996)                              NaN
#        12 Angry Men (1957)                                NaN
#        187 (1997)                                         NaN
#
#                                                                               \
# title                            3 Ninjas: High Noon At Mega Mountain (1998)
#        title
# rating 'Til There Was You (1997)                                         NaN
#        1-900 (1994)                                                      NaN
#        101 Dalmatians (1996)                                             NaN
#        12 Angry Men (1957)                                               NaN
#        187 (1997)                                                        NaN
#
#                                                                     \
# title                            39 Steps, The (1935) 8 1/2 (1963)
#        title
# rating 'Til There Was You (1997)                  NaN          NaN
#        1-900 (1994)                               NaN          NaN
#        101 Dalmatians (1996)                      NaN          NaN
#        12 Angry Men (1957)                        NaN          NaN
#        187 (1997)                                 NaN          NaN
#
#                                                                  \
# title                            8 Heads in a Duffel Bag (1997)
#        title
# rating 'Til There Was You (1997)                            NaN
#        1-900 (1994)                                         NaN
#        101 Dalmatians (1996)                                NaN
#        12 Angry Men (1957)                                  NaN
#        187 (1997)                                           NaN
#
#                                                    \
# title                            8 Seconds (1994)
#        title
# rating 'Til There Was You (1997)              NaN
#        1-900 (1994)                           NaN
#        101 Dalmatians (1996)                  NaN
#        12 Angry Men (1957)                    NaN
#        187 (1997)                             NaN
#
#                                                                      \
# title                            ? k?ldum klaka (Cold Fever) (1994)
#        title
# rating 'Til There Was You (1997)                                NaN
#        1-900 (1994)                                             NaN
#        101 Dalmatians (1996)                                    NaN
#        12 Angry Men (1957)                                      NaN
#        187 (1997)                                               NaN
#
#                                                                              \
# title                            A Chef in Love (1996) Above the Rim (1994)
#        title
# rating 'Til There Was You (1997)                   NaN                  NaN
#        1-900 (1994)                                NaN                  NaN
#        101 Dalmatians (1996)                       NaN                  NaN
#        12 Angry Men (1957)                         NaN                  NaN
#        187 (1997)                                  NaN                  NaN
#
#                                                                           \
# title                            Absolute Power (1997) Abyss, The (1989)
#        title
# rating 'Til There Was You (1997)                   NaN               NaN
#        1-900 (1994)                                NaN               NaN
#        101 Dalmatians (1996)                       NaN               NaN
#        12 Angry Men (1957)                         NaN               NaN
#        187 (1997)                                  NaN               NaN
#
#                                                                     \
# title                            Ace Ventura: Pet Detective (1994)
#        title
# rating 'Til There Was You (1997)                               NaN
#        1-900 (1994)                                            NaN
#        101 Dalmatians (1996)                                   NaN
#        12 Angry Men (1957)                                     NaN
#        187 (1997)                                              NaN
#
#                                                                         \
# title                            Ace Ventura: When Nature Calls (1995)
#        title
# rating 'Til There Was You (1997)                                   NaN
#        1-900 (1994)                                                NaN
#        101 Dalmatians (1996)                                       NaN
#        12 Angry Men (1957)                                         NaN
#        187 (1997)                                                  NaN
#
#                                                                 \
# title                            Across the Sea of Time (1995)
#        title
# rating 'Til There Was You (1997)                           NaN
#        1-900 (1994)                                        NaN
#        101 Dalmatians (1996)                               NaN
#        12 Angry Men (1957)                                 NaN
#        187 (1997)                                          NaN
#
#                                                               \
# title                            Addams Family Values (1993)
#        title
# rating 'Til There Was You (1997)                         NaN
#        1-900 (1994)                                      NaN
#        101 Dalmatians (1996)                             NaN
#        12 Angry Men (1957)                               NaN
#        187 (1997)                                        NaN
#
#                                                           \
# title                            Addicted to Love (1997)
#        title
# rating 'Til There Was You (1997)                     NaN
#        1-900 (1994)                                  NaN
#        101 Dalmatians (1996)                         NaN
#        12 Angry Men (1957)                           NaN
#        187 (1997)                                    NaN
#
#                                                         \
# title                            Addiction, The (1995)
#        title
# rating 'Til There Was You (1997)                   NaN
#        1-900 (1994)                                NaN
#        101 Dalmatians (1996)                       NaN
#        12 Angry Men (1957)                         NaN
#        187 (1997)                                  NaN
#
#                                                                       \
# title                            Adventures of Pinocchio, The (1996)
#        title
# rating 'Til There Was You (1997)                                 NaN
#        1-900 (1994)                                              NaN
#        101 Dalmatians (1996)                                     NaN
#        12 Angry Men (1957)                                       NaN
#        187 (1997)                                                NaN
#
#                                                                                            \
# title                            Adventures of Priscilla, Queen of the Desert, The (1994)
#        title
# rating 'Til There Was You (1997)                                                NaN
#        1-900 (1994)                                                             NaN
#        101 Dalmatians (1996)                                                    NaN
#        12 Angry Men (1957)                                                      NaN
#        187 (1997)                                                               NaN
#
#                                                                        \
# title                            Adventures of Robin Hood, The (1938)
#        title
# rating 'Til There Was You (1997)                                  NaN
#        1-900 (1994)                                               NaN
#        101 Dalmatians (1996)                                      NaN
#        12 Angry Men (1957)                                        NaN
#        187 (1997)                                                 NaN
#
#                                                                 \
# title                            Affair to Remember, An (1957)
#        title
# rating 'Til There Was You (1997)                           NaN
#        1-900 (1994)                                        NaN
#        101 Dalmatians (1996)                               NaN
#        12 Angry Men (1957)                                 NaN
#        187 (1997)                                          NaN
#
#                                                                              \
# title                            African Queen, The (1951) Afterglow (1997)
#        title
# rating 'Til There Was You (1997)                       NaN              NaN
#        1-900 (1994)                                    NaN              NaN
#        101 Dalmatians (1996)                           NaN              NaN
#        12 Angry Men (1957)                             NaN              NaN
#        187 (1997)                                      NaN              NaN
#
#                                                                \
# title                            Age of Innocence, The (1993)
#        title
# rating 'Til There Was You (1997)                          NaN
#        1-900 (1994)                                       NaN
#        101 Dalmatians (1996)                              NaN
#        12 Angry Men (1957)                                NaN
#        187 (1997)                                         NaN
#
#                                                                       \
# title                            Aiqing wansui (1994) Air Bud (1997)
#        title
# rating 'Til There Was You (1997)                  NaN            NaN
#        1-900 (1994)                               NaN            NaN
#        101 Dalmatians (1996)                      NaN            NaN
#        12 Angry Men (1957)                        NaN            NaN
#        187 (1997)                                 NaN            NaN
#
#                                                        \
# title                            Air Force One (1997)
#        title
# rating 'Til There Was You (1997)                  NaN
#        1-900 (1994)                               NaN
#        101 Dalmatians (1996)                      NaN
#        12 Angry Men (1957)                        NaN
#        187 (1997)                                 NaN
#
#                                                                            \
# title                            Air Up There, The (1994) Airheads (1994)
#        title
# rating 'Til There Was You (1997)                      NaN             NaN
#        1-900 (1994)                                   NaN             NaN
#        101 Dalmatians (1996)                          NaN             NaN
#        12 Angry Men (1957)                            NaN             NaN
#        187 (1997)                                     NaN             NaN
#
#                                                               \
# title                            Akira (1988) Aladdin (1992)
#        title
# rating 'Til There Was You (1997)          NaN            NaN
#        1-900 (1994)                       NaN            NaN
#        101 Dalmatians (1996)              NaN            NaN
#        12 Angry Men (1957)                NaN            NaN
#        187 (1997)                         NaN            NaN
#
#                                                                          \
# title                            Aladdin and the King of Thieves (1996)
#        title
# rating 'Til There Was You (1997)                                    NaN
#        1-900 (1994)                                                 NaN
#        101 Dalmatians (1996)                                        NaN
#        12 Angry Men (1957)                                          NaN
#        187 (1997)                                                   NaN
#
#                                                                         \
# title                            Alaska (1996) Albino Alligator (1996)
#        title
# rating 'Til There Was You (1997)           NaN                     NaN
#        1-900 (1994)                        NaN                     NaN
#        101 Dalmatians (1996)               NaN                     NaN
#        12 Angry Men (1957)                 NaN                     NaN
#        187 (1997)                          NaN                     NaN
#
#                                                                           \
# title                            Alice in Wonderland (1951) Alien (1979)
#        title
# rating 'Til There Was You (1997)                        NaN          NaN
#        1-900 (1994)                                     NaN          NaN
#        101 Dalmatians (1996)                            NaN          NaN
#        12 Angry Men (1957)                              NaN          NaN
#        187 (1997)                                       NaN          NaN
#
#                                                                             \
# title                            Alien 3 (1992) Alien: Resurrection (1997)
#        title
# rating 'Til There Was You (1997)            NaN                        NaN
#        1-900 (1994)                         NaN                        NaN
#        101 Dalmatians (1996)                NaN                        NaN
#        12 Angry Men (1957)                  NaN                        NaN
#        187 (1997)                           NaN                        NaN
#
#                                                                      \
# title                            Aliens (1986) All About Eve (1950)
#        title
# rating 'Til There Was You (1997)           NaN                  NaN
#        1-900 (1994)                        NaN                  NaN
#        101 Dalmatians (1996)               NaN                  NaN
#        12 Angry Men (1957)                 NaN                  NaN
#        187 (1997)                          NaN                  NaN
#
#                                                                  \
# title                            All Dogs Go to Heaven 2 (1996)
#        title
# rating 'Til There Was You (1997)                            NaN
#        1-900 (1994)                                         NaN
#        101 Dalmatians (1996)                                NaN
#        12 Angry Men (1957)                                  NaN
#        187 (1997)                                           NaN
#
#                                                                             \
# title                            All Over Me (1997) All Things Fair (1996)
#        title
# rating 'Til There Was You (1997)                NaN                    NaN
#        1-900 (1994)                             NaN                    NaN
#        101 Dalmatians (1996)                    NaN                    NaN
#        12 Angry Men (1957)                      NaN                    NaN
#        187 (1997)                               NaN                    NaN
#
#                                                                    \
# title                            Alphaville (1965) Amadeus (1984)
#        title
# rating 'Til There Was You (1997)               NaN            NaN
#        1-900 (1994)                            NaN            NaN
#        101 Dalmatians (1996)                   NaN            NaN
#        12 Angry Men (1957)                     NaN            NaN
#        187 (1997)                              NaN            NaN
#
#                                                  \
# title                            Amateur (1994)
#        title
# rating 'Til There Was You (1997)            NaN
#        1-900 (1994)                         NaN
#        101 Dalmatians (1996)                NaN
#        12 Angry Men (1957)                  NaN
#        187 (1997)                           NaN
#
#                                                                       \
# title                            Amazing Panda Adventure, The (1995)
#        title
# rating 'Til There Was You (1997)                                 NaN
#        1-900 (1994)                                              NaN
#        101 Dalmatians (1996)                                     NaN
#        12 Angry Men (1957)                                       NaN
#        187 (1997)                                                NaN
#
#                                                           \
# title                            American Buffalo (1996)
#        title
# rating 'Til There Was You (1997)                     NaN
#        1-900 (1994)                                  NaN
#        101 Dalmatians (1996)                         NaN
#        12 Angry Men (1957)                           NaN
#        187 (1997)                                    NaN
#
#                                                         \
# title                            American Dream (1990)
#        title
# rating 'Til There Was You (1997)                   NaN
#        1-900 (1994)                                NaN
#        101 Dalmatians (1996)                       NaN
#        12 Angry Men (1957)                         NaN
#        187 (1997)                                  NaN
#
#                                                                  \
# title                            American President, The (1995)
#        title
# rating 'Til There Was You (1997)                            NaN
#        1-900 (1994)                                         NaN
#        101 Dalmatians (1996)                                NaN
#        12 Angry Men (1957)                                  NaN
#        187 (1997)                                           NaN
#
#                                                          \
# title                            American Strays (1996)
#        title
# rating 'Til There Was You (1997)                    NaN
#        1-900 (1994)                                 NaN
#        101 Dalmatians (1996)                        NaN
#        12 Angry Men (1957)                          NaN
#        187 (1997)                                   NaN
#
#                                                                          \
# title                            American Werewolf in London, An (1981)
#        title
# rating 'Til There Was You (1997)                                    NaN
#        1-900 (1994)                                                 NaN
#        101 Dalmatians (1996)                                        NaN
#        12 Angry Men (1957)                                          NaN
#        187 (1997)                                                   NaN
#
#                                                                               \
# title                            American in Paris, An (1951) Amistad (1997)
#        title
# rating 'Til There Was You (1997)                          NaN            NaN
#        1-900 (1994)                                       NaN            NaN
#        101 Dalmatians (1996)                              NaN            NaN
#        12 Angry Men (1957)                                NaN            NaN
#        187 (1997)                                         NaN            NaN
#
#                                                                           \
# title                            Amityville 1992: It's About Time (1992)
#        title
# rating 'Til There Was You (1997)                                     NaN
#        1-900 (1994)                                                  NaN
#        101 Dalmatians (1996)                                         NaN
#        12 Angry Men (1957)                                           NaN
#        187 (1997)                                                    NaN
#
#                                                         \
# title                            Amityville 3-D (1983)
#        title
# rating 'Til There Was You (1997)                   NaN
#        1-900 (1994)                                NaN
#        101 Dalmatians (1996)                       NaN
#        12 Angry Men (1957)                         NaN
#        187 (1997)                                  NaN
#
#                                                                \
# title                            Amityville Curse, The (1990)
#        title
# rating 'Til There Was You (1997)                          NaN
#        1-900 (1994)                                       NaN
#        101 Dalmatians (1996)                              NaN
#        12 Angry Men (1957)                                NaN
#        187 (1997)                                         NaN
#
#                                                                 \
# title                            Amityville Horror, The (1979)
#        title
# rating 'Til There Was You (1997)                           NaN
#        1-900 (1994)                                        NaN
#        101 Dalmatians (1996)                               NaN
#        12 Angry Men (1957)                                 NaN
#        187 (1997)                                          NaN
#
#                                                                        \
# title                            Amityville II: The Possession (1982)
#        title
# rating 'Til There Was You (1997)                                  NaN
#        1-900 (1994)                                               NaN
#        101 Dalmatians (1996)                                      NaN
#        12 Angry Men (1957)                                        NaN
#        187 (1997)                                                 NaN
#
#                                                                       \
# title                            Amityville: A New Generation (1993)
#        title
# rating 'Til There Was You (1997)                                 NaN
#        1-900 (1994)                                              NaN
#        101 Dalmatians (1996)                                     NaN
#        12 Angry Men (1957)                                       NaN
#        187 (1997)                                                NaN
#
#                                                                \
# title                            Amityville: Dollhouse (1996)
#        title
# rating 'Til There Was You (1997)                          NaN
#        1-900 (1994)                                       NaN
#        101 Dalmatians (1996)                              NaN
#        12 Angry Men (1957)                                NaN
#        187 (1997)                                         NaN
#
#                                                        \
# title                            Amos & Andrew (1993)
#        title
# rating 'Til There Was You (1997)                  NaN
#        1-900 (1994)                               NaN
#        101 Dalmatians (1996)                      NaN
#        12 Angry Men (1957)                        NaN
#        187 (1997)                                 NaN
#
#                                                                  \
# title                            An Unforgettable Summer (1994)
#        title
# rating 'Til There Was You (1997)                            NaN
#        1-900 (1994)                                         NaN
#        101 Dalmatians (1996)                                NaN
#        12 Angry Men (1957)                                  NaN
#        187 (1997)                                           NaN
#
#                                                                    \
# title                            Anaconda (1997) Anastasia (1997)
#        title
# rating 'Til There Was You (1997)             NaN              NaN
#        1-900 (1994)                          NaN              NaN
#        101 Dalmatians (1996)                 NaN              NaN
#        12 Angry Men (1957)                   NaN              NaN
#        187 (1997)                            NaN              NaN
#
#                                                                  \
# title                            Andre (1994) Angel Baby (1995)
#        title
# rating 'Til There Was You (1997)          NaN               NaN
#        1-900 (1994)                       NaN               NaN
#        101 Dalmatians (1996)              NaN               NaN
#        12 Angry Men (1957)                NaN               NaN
#        187 (1997)                         NaN               NaN
#
#                                                               \
# title                            Angel and the Badman (1947)
#        title
# rating 'Til There Was You (1997)                         NaN
#        1-900 (1994)                                      NaN
#        101 Dalmatians (1996)                             NaN
#        12 Angry Men (1957)                               NaN
#        187 (1997)                                        NaN
#
#                                                                             \
# title                            Angel on My Shoulder (1946) Angela (1995)
#        title
# rating 'Til There Was You (1997)                         NaN           NaN
#        1-900 (1994)                                      NaN           NaN
#        101 Dalmatians (1996)                             NaN           NaN
#        12 Angry Men (1957)                               NaN           NaN
#        187 (1997)                                        NaN           NaN
#
#                                                             \
# title                            Angels and Insects (1995)
#        title
# rating 'Til There Was You (1997)                       NaN
#        1-900 (1994)                                    NaN
#        101 Dalmatians (1996)                           NaN
#        12 Angry Men (1957)                             NaN
#        187 (1997)                                      NaN
#
#                                                                              \
# title                            Angels in the Outfield (1994) Angus (1995)
#        title
# rating 'Til There Was You (1997)                           NaN          NaN
#        1-900 (1994)                                        NaN          NaN
#        101 Dalmatians (1996)                               NaN          NaN
#        12 Angry Men (1957)                                 NaN          NaN
#        187 (1997)                                          NaN          NaN
#
#                                                                    \
# title                            Anna (1996) Anna Karenina (1997)
#        title
# rating 'Til There Was You (1997)         NaN                  NaN
#        1-900 (1994)                      NaN                  NaN
#        101 Dalmatians (1996)             NaN                  NaN
#        12 Angry Men (1957)               NaN                  NaN
#        187 (1997)                        NaN                  NaN
#
#                                                                \
# title                            Anne Frank Remembered (1995)
#        title
# rating 'Til There Was You (1997)                          NaN
#        1-900 (1994)                                       NaN
#        101 Dalmatians (1996)                              NaN
#        12 Angry Men (1957)                                NaN
#        187 (1997)                                         NaN
#
#                                                                             \
# title                            Annie Hall (1977) Another Stakeout (1993)
#        title
# rating 'Til There Was You (1997)               NaN                     NaN
#        1-900 (1994)                            NaN                     NaN
#        101 Dalmatians (1996)                   NaN                     NaN
#        12 Angry Men (1957)                     NaN                     NaN
#        187 (1997)                              NaN                     NaN
#
#                                                                          \
# title                            Antonia's Line (1995) Aparajito (1956)
#        title
# rating 'Til There Was You (1997)                   NaN              NaN
#        1-900 (1994)                                NaN              NaN
#        101 Dalmatians (1996)                       NaN              NaN
#        12 Angry Men (1957)                         NaN              NaN
#        187 (1997)                                  NaN              NaN
#
#                                                                               \
# title                            Apartment, The (1960) Apocalypse Now (1979)
#        title
# rating 'Til There Was You (1997)                   NaN                   NaN
#        1-900 (1994)                                NaN                   NaN
#        101 Dalmatians (1996)                       NaN                   NaN
#        12 Angry Men (1957)                         NaN                   NaN
#        187 (1997)                                  NaN                   NaN
#
#                                                                        \
# title                            Apollo 13 (1995) Apostle, The (1997)
#        title
# rating 'Til There Was You (1997)              NaN                 NaN
#        1-900 (1994)                           NaN                 NaN
#        101 Dalmatians (1996)                  NaN                 NaN
#        12 Angry Men (1957)                    NaN                 NaN
#        187 (1997)                             NaN                 NaN
#
#                                                                   \
# title                            Apple Dumpling Gang, The (1975)
#        title
# rating 'Til There Was You (1997)                             NaN
#        1-900 (1994)                                          NaN
#        101 Dalmatians (1996)                                 NaN
#        12 Angry Men (1957)                                   NaN
#        187 (1997)                                            NaN
#
#                                                                            \
# title                            April Fool's Day (1986) Apt Pupil (1998)
#        title
# rating 'Til There Was You (1997)                     NaN              NaN
#        1-900 (1994)                                  NaN              NaN
#        101 Dalmatians (1996)                         NaN              NaN
#        12 Angry Men (1957)                           NaN              NaN
#        187 (1997)                                    NaN              NaN
#
#                                                          \
# title                            Aristocats, The (1970)
#        title
# rating 'Til There Was You (1997)                    NaN
#        1-900 (1994)                                 NaN
#        101 Dalmatians (1996)                        NaN
#        12 Angry Men (1957)                          NaN
#        187 (1997)                                   NaN
#
#                                                           \
# title                            Army of Darkness (1993)
#        title
# rating 'Til There Was You (1997)                     NaN
#        1-900 (1994)                                  NaN
#        101 Dalmatians (1996)                         NaN
#        12 Angry Men (1957)                           NaN
#        187 (1997)                                    NaN
#
#                                                                      \
# title                            Around the World in 80 Days (1956)
#        title
# rating 'Til There Was You (1997)                                NaN
#        1-900 (1994)                                             NaN
#        101 Dalmatians (1996)                                    NaN
#        12 Angry Men (1957)                                      NaN
#        187 (1997)                                               NaN
#
#                                                       \
# title                            Arrival, The (1996)
#        title
# rating 'Til There Was You (1997)                 NaN
#        1-900 (1994)                              NaN
#        101 Dalmatians (1996)                     NaN
#        12 Angry Men (1957)                       NaN
#        187 (1997)                                NaN
#
#                                                               \
# title                            Arsenic and Old Lace (1944)
#        title
# rating 'Til There Was You (1997)                         NaN
#        1-900 (1994)                                      NaN
#        101 Dalmatians (1996)                             NaN
#        12 Angry Men (1957)                               NaN
#        187 (1997)                                        NaN
#
#                                                                              \
# title                            As Good As It Gets (1997) Assassins (1995)
#        title
# rating 'Til There Was You (1997)                       NaN              NaN
#        1-900 (1994)                                    NaN              NaN
#        101 Dalmatians (1996)                           NaN              NaN
#        12 Angry Men (1957)                             NaN              NaN
#        187 (1997)                                      NaN              NaN
#
#                                                                                \
# title                            Assignment, The (1997) Associate, The (1996)
#        title
# rating 'Til There Was You (1997)                    NaN                   NaN
#        1-900 (1994)                                 NaN                   NaN
#        101 Dalmatians (1996)                        NaN                   NaN
#        12 Angry Men (1957)                          NaN                   NaN
#        187 (1997)                                   NaN                   NaN
#
#                                                                    \
# title                            Audrey Rose (1977) August (1996)
#        title
# rating 'Til There Was You (1997)                NaN           NaN
#        1-900 (1994)                             NaN           NaN
#        101 Dalmatians (1996)                    NaN           NaN
#        12 Angry Men (1957)                      NaN           NaN
#        187 (1997)                               NaN           NaN
#
#                                                                                      \
# title                            Austin Powers: International Man of Mystery (1997)
#        title
# rating 'Til There Was You (1997)                                                NaN
#        1-900 (1994)                                                             NaN
#        101 Dalmatians (1996)                                                    NaN
#        12 Angry Men (1957)                                                      NaN
#        187 (1997)                                                               NaN
#
#                                                                    \
# title                            Awfully Big Adventure, An (1995)
#        title
# rating 'Til There Was You (1997)                              NaN
#        1-900 (1994)                                           NaN
#        101 Dalmatians (1996)                                  NaN
#        12 Angry Men (1957)                                    NaN
#        187 (1997)                                             NaN
#
#                                                                    \
# title                            Ayn Rand: A Sense of Life (1997)
#        title
# rating 'Til There Was You (1997)                              NaN
#        1-900 (1994)                                           NaN
#        101 Dalmatians (1996)                                  NaN
#        12 Angry Men (1957)                                    NaN
#        187 (1997)                                             NaN
#
#                                                                               \
# title                            B*A*P*S (1997) B. Monkey (1998) Babe (1995)
#        title
# rating 'Til There Was You (1997)            NaN              NaN         NaN
#        1-900 (1994)                         NaN              NaN         NaN
#        101 Dalmatians (1996)                NaN              NaN         NaN
#        12 Angry Men (1957)                  NaN              NaN         NaN
#        187 (1997)                           NaN              NaN         NaN
#
#                                                                 \
# title                            Baby-Sitters Club, The (1995)
#        title
# rating 'Til There Was You (1997)                           NaN
#        1-900 (1994)                                        NaN
#        101 Dalmatians (1996)                               NaN
#        12 Angry Men (1957)                                 NaN
#        187 (1997)                                          NaN
#
#                                                                           \
# title                            Babyfever (1994) Babysitter, The (1995)
#        title
# rating 'Til There Was You (1997)              NaN                    NaN
#        1-900 (1994)                           NaN                    NaN
#        101 Dalmatians (1996)                  NaN                    NaN
#        12 Angry Men (1957)                    NaN                    NaN
#        187 (1997)                             NaN                    NaN
#
#                                                                             \
# title                            Back to the Future (1985) Backbeat (1993)
#        title
# rating 'Til There Was You (1997)                       NaN             NaN
#        1-900 (1994)                                    NaN             NaN
#        101 Dalmatians (1996)                           NaN             NaN
#        12 Angry Men (1957)                             NaN             NaN
#        187 (1997)                                      NaN             NaN
#
#                                                                      \
# title                            Bad Boys (1995) Bad Company (1995)
#        title
# rating 'Til There Was You (1997)             NaN                NaN
#        1-900 (1994)                          NaN                NaN
#        101 Dalmatians (1996)                 NaN                NaN
#        12 Angry Men (1957)                   NaN                NaN
#        187 (1997)                            NaN                NaN
#
#                                                                    \
# title                            Bad Girls (1994) Bad Moon (1996)
#        title
# rating 'Til There Was You (1997)              NaN             NaN
#        1-900 (1994)                           NaN             NaN
#        101 Dalmatians (1996)                  NaN             NaN
#        12 Angry Men (1957)                    NaN             NaN
#        187 (1997)                             NaN             NaN
#
#                                                    \
# title                            Bad Taste (1987)
#        title
# rating 'Til There Was You (1997)              NaN
#        1-900 (1994)                           NaN
#        101 Dalmatians (1996)                  NaN
#        12 Angry Men (1957)                    NaN
#        187 (1997)                             NaN
#
#                                                                                     \
# title                            Ballad of Narayama, The (Narayama Bushiko) (1958)
#        title
# rating 'Til There Was You (1997)                                               NaN
# ...
#
#                                                                \
# title                            Whole Wide World, The (1996)
#        title
# rating 'Til There Was You (1997)                          NaN
#        1-900 (1994)                                       NaN
#        101 Dalmatians (1996)                              NaN
#        12 Angry Men (1957)                                NaN
#        187 (1997)                                         NaN
#
#                                                                        \
# title                            Widows' Peak (1994) Wife, The (1995)
#        title
# rating 'Til There Was You (1997)                 NaN              NaN
#        1-900 (1994)                              NaN              NaN
#        101 Dalmatians (1996)                     NaN              NaN
#        12 Angry Men (1957)                       NaN              NaN
#        187 (1997)                                NaN              NaN
#
#                                                                        \
# title                            Wild America (1997) Wild Bill (1995)
#        title
# rating 'Til There Was You (1997)                 NaN              NaN
#        1-900 (1994)                              NaN              NaN
#        101 Dalmatians (1996)                     NaN              NaN
#        12 Angry Men (1957)                       NaN              NaN
#        187 (1997)                                NaN              NaN
#
#                                                                            \
# title                            Wild Bunch, The (1969) Wild Reeds (1994)
#        title
# rating 'Til There Was You (1997)                    NaN               NaN
#        1-900 (1994)                                 NaN               NaN
#        101 Dalmatians (1996)                        NaN               NaN
#        12 Angry Men (1957)                          NaN               NaN
#        187 (1997)                                   NaN               NaN
#
#                                                      \
# title                            Wild Things (1998)
#        title
# rating 'Til There Was You (1997)                NaN
#        1-900 (1994)                             NaN
#        101 Dalmatians (1996)                    NaN
#        12 Angry Men (1957)                      NaN
#        187 (1997)                               NaN
#
#                                                                                 \
# title                            William Shakespeare's Romeo and Juliet (1996)
#        title
# rating 'Til There Was You (1997)                                           NaN
#        1-900 (1994)                                                        NaN
#        101 Dalmatians (1996)                                               NaN
#        12 Angry Men (1957)                                                 NaN
#        187 (1997)                                                          NaN
#
#                                                                                \
# title                            Willy Wonka and the Chocolate Factory (1971)
#        title
# rating 'Til There Was You (1997)                                          NaN
#        1-900 (1994)                                                       NaN
#        101 Dalmatians (1996)                                              NaN
#        12 Angry Men (1957)                                                NaN
#        187 (1997)                                                         NaN
#
#                                                          \
# title                            Window to Paris (1994)
#        title
# rating 'Til There Was You (1997)                    NaN
#        1-900 (1994)                                 NaN
#        101 Dalmatians (1996)                        NaN
#        12 Angry Men (1957)                          NaN
#        187 (1997)                                   NaN
#
#                                                           \
# title                            Wings of Courage (1995)
#        title
# rating 'Til There Was You (1997)                     NaN
#        1-900 (1994)                                  NaN
#        101 Dalmatians (1996)                         NaN
#        12 Angry Men (1957)                           NaN
#        187 (1997)                                    NaN
#
#                                                          \
# title                            Wings of Desire (1987)
#        title
# rating 'Til There Was You (1997)                    NaN
#        1-900 (1994)                                 NaN
#        101 Dalmatians (1996)                        NaN
#        12 Angry Men (1957)                          NaN
#        187 (1997)                                   NaN
#
#                                                                 \
# title                            Wings of the Dove, The (1997)
#        title
# rating 'Til There Was You (1997)                           NaN
#        1-900 (1994)                                        NaN
#        101 Dalmatians (1996)                               NaN
#        12 Angry Men (1957)                                 NaN
#        187 (1997)                                          NaN
#
#                                                                               \
# title                            Winnie the Pooh and the Blustery Day (1968)
#        title
# rating 'Til There Was You (1997)                                         NaN
#        1-900 (1994)                                                      NaN
#        101 Dalmatians (1996)                                             NaN
#        12 Angry Men (1957)                                               NaN
#        187 (1997)                                                        NaN
#
#                                                                              \
# title                            Winter Guest, The (1997) Wishmaster (1997)
#        title
# rating 'Til There Was You (1997)                      NaN               NaN
#        1-900 (1994)                                   NaN               NaN
#        101 Dalmatians (1996)                          NaN               NaN
#        12 Angry Men (1957)                            NaN               NaN
#        187 (1997)                                     NaN               NaN
#
#                                                                            \
# title                            With Honors (1994) Withnail and I (1987)
#        title
# rating 'Til There Was You (1997)                NaN                   NaN
#        1-900 (1994)                             NaN                   NaN
#        101 Dalmatians (1996)                    NaN                   NaN
#        12 Angry Men (1957)                      NaN                   NaN
#        187 (1997)                               NaN                   NaN
#
#                                                                           \
# title                            Witness (1985) Wizard of Oz, The (1939)
#        title
# rating 'Til There Was You (1997)            NaN                      NaN
#        1-900 (1994)                         NaN                      NaN
#        101 Dalmatians (1996)                NaN                      NaN
#        12 Angry Men (1957)                  NaN                      NaN
#        187 (1997)                           NaN                      NaN
#
#                                                                             \
# title                            Wolf (1994) Woman in Question, The (1950)
#        title
# rating 'Til There Was You (1997)         NaN                           NaN
#        1-900 (1994)                      NaN                           NaN
#        101 Dalmatians (1996)             NaN                           NaN
#        12 Angry Men (1957)               NaN                           NaN
#        187 (1997)                        NaN                           NaN
#
#                                                     \
# title                            Women, The (1939)
#        title
# rating 'Til There Was You (1997)               NaN
#        1-900 (1994)                            NaN
#        101 Dalmatians (1996)                   NaN
#        12 Angry Men (1957)                     NaN
#        187 (1997)                              NaN
#
#                                                                                            \
# title                            Wonderful, Horrible Life of Leni Riefenstahl, The (1993)
#        title
# rating 'Til There Was You (1997)                                                NaN
#        1-900 (1994)                                                             NaN
#        101 Dalmatians (1996)                                                    NaN
#        12 Angry Men (1957)                                                      NaN
#        187 (1997)                                                               NaN
#
#                                                     \
# title                            Wonderland (1997)
#        title
# rating 'Til There Was You (1997)               NaN
#        1-900 (1994)                            NaN
#        101 Dalmatians (1996)                   NaN
#        12 Angry Men (1957)                     NaN
#        187 (1997)                              NaN
#
#                                                                           \
# title                            Wooden Man's Bride, The (Wu Kui) (1994)
#        title
# rating 'Til There Was You (1997)                                     NaN
#        1-900 (1994)                                                  NaN
#        101 Dalmatians (1996)                                         NaN
#        12 Angry Men (1957)                                           NaN
#        187 (1997)                                                    NaN
#
#                                                                          \
# title                            World of Apu, The (Apur Sansar) (1959)
#        title
# rating 'Til There Was You (1997)                                    NaN
#        1-900 (1994)                                                 NaN
#        101 Dalmatians (1996)                                        NaN
#        12 Angry Men (1957)                                          NaN
#        187 (1997)                                                   NaN
#
#                                                                                \
# title                            Wrong Trousers, The (1993) Wyatt Earp (1994)
#        title
# rating 'Til There Was You (1997)                        NaN               NaN
#        1-900 (1994)                                     NaN               NaN
#        101 Dalmatians (1996)                            NaN               NaN
#        12 Angry Men (1957)                              NaN               NaN
#        187 (1997)                                       NaN               NaN
#
#                                                                               \
# title                            Yankee Zulu (1994) Year of the Horse (1997)
#        title
# rating 'Til There Was You (1997)                NaN                      NaN
#        1-900 (1994)                             NaN                      NaN
#        101 Dalmatians (1996)                    NaN                      NaN
#        12 Angry Men (1957)                      NaN                      NaN
#        187 (1997)                               NaN                      NaN
#
#                                                       \
# title                            You So Crazy (1994)
#        title
# rating 'Til There Was You (1997)                 NaN
#        1-900 (1994)                              NaN
#        101 Dalmatians (1996)                     NaN
#        12 Angry Men (1957)                       NaN
#        187 (1997)                                NaN
#
#                                                                               \
# title                            Young Frankenstein (1974) Young Guns (1988)
#        title
# rating 'Til There Was You (1997)                       NaN               NaN
#        1-900 (1994)                                    NaN               NaN
#        101 Dalmatians (1996)                           NaN               NaN
#        12 Angry Men (1957)                             NaN               NaN
#        187 (1997)                                      NaN               NaN
#
#                                                        \
# title                            Young Guns II (1990)
#        title
# rating 'Til There Was You (1997)                  NaN
#        1-900 (1994)                               NaN
#        101 Dalmatians (1996)                      NaN
#        12 Angry Men (1957)                        NaN
#        187 (1997)                                 NaN
#
#                                                                         \
# title                            Young Poisoner's Handbook, The (1995)
#        title
# rating 'Til There Was You (1997)                                   NaN
#        1-900 (1994)                                                NaN
#        101 Dalmatians (1996)                                       NaN
#        12 Angry Men (1957)                                         NaN
#        187 (1997)                                                  NaN
#
#
# title                            Zeus and Roxanne (1997) unknown
#        title
# rating 'Til There Was You (1997)                     NaN     NaN
#        1-900 (1994)                                  NaN     NaN
#        101 Dalmatians (1996)                         NaN     NaN
#        12 Angry Men (1957)                           NaN     NaN
#        187 (1997)                                    NaN     NaN
#
# [5 rows x 1664 columns]

# %% [markdown]
# Well, Pandas keeps making it easy for us, and has a corrwith function that you can see in the following code that we can use:

# %%
movieRatings1 = movieRatings['rating']
movieRatings1
similarMovies = movieRatings1.corrwith(starWarsRatings)
# print(similarMovies.shape)
similarMovies = similarMovies.dropna()
df = pd.DataFrame(similarMovies)
similarMovies.sort_values(ascending=False)
# print(similarMovies.shape)
# Out:
# title
# No Escape (1994)                          1.0
# Man of the Year (1995)                    1.0
# Hollow Reed (1996)                        1.0
# Commandments (1997)                       1.0
# Cosi (1996)                               1.0
#                                          ...
# Theodore Rex (1995)                      -1.0
# I Like It Like That (1994)               -1.0
# Two Deaths (1995)                        -1.0
# Roseanna's Grave (For Roseanna) (1997)   -1.0
# Frankie Starlight (1995)                 -1.0
# Length: 1410, dtype: float64

# %% [markdown]
# That code will go ahead and correlate a given column with every other column in the DataFrame, and compute the correlation scores and give that back to us. So, what we're doing here is using corrwith on the entire movieRatings DataFrame, that's that entire matrix of user movie ratings, correlating it with just the starWarsRatings column, and then dropping all of the missing results with dropna. So, that just leaves us with items that had a correlation, where there was more than one person that viewed it, and we create a new DataFrame based on those results and then display the top 10 results. So again, just to recap:
#
# 1. We're going to build the correlation score between Star Wars and every other movie.
# 2. Drop all the NaN values, so that we only have movie similarities that actually exist, where more than one person rated it.
# 3. And, we're going to construct a new DataFrame from the results and look at the top 10 results.
#
# We ended up with this result of correlation scores between each individual movie for Star Wars and we can see, for example, a surprisingly high correlation score with the movie `Til There Was You (1997)`, a negative correlation with the movie `1-900 (1994)`, and a very weak correlation with `101 Dalmatians (1996)`.
#
# Now, all we should have to do is sort this by similarity score, and we should have the top movie similarities for Star Wars, right? Let's go ahead and do that.
#
# Just call sort_values on the resulting DataFrame, again Pandas makes it really easy, and we can say `ascending=False`, to actually get it sorted in reverse order by correlation score. So, let's do that:
#
# Okay, so `Star Wars (1977)` came out pretty close to top, because it is similar to itself, but what's all this other stuff? What the heck? We can see in the preceding output, some movies such as: `Full Speed (1996)`, `Man of the Year (1995)`, `The Outlaw (1943)`. These are all, you know, fairly obscure movies, that most of them I've never even heard of, and yet they have perfect correlations with Star Wars. That's kinda weird! So, obviously we're doing something wrong here. What could it be?
#
# Well, it turns out there's a perfectly reasonable explanation, and this is a good lesson in why you always need to examine your results when you're done with any sort of data science task-question the results, because often there's something you missed, there might be something you need to clean in your data, there might be something you did wrong. But you should also always look skeptically at your results, don't just take them on faith, okay? If you do so, you're going to get in trouble, because if I were to actually present these as recommendations to people who liked Star Wars, I would get fired. Don't get fired! Pay attention to your results! So, let's dive into what went wrong in our next section.

# %% [markdown]
# ## Improving the results of movie similarities

# %% [markdown]
# Let's figure out what went wrong with our movie similarities there. We went through all this exciting work to compute correlation scores between movies based on their user ratings vectors, and the result we got kind of sucked. so just to remind you, we looked for movies that are similar to Star Wars using that technique, and we ended up with a bunch of weird recommendation at the top that had a perfect correlation.
#
# And, most of them were very obscure movies. So, What do you think might be going on there? Well, one think that might make sense is, Let's say we have a lot of people wathch Star Wars and some other obscure film. We'd end up with a good correlation between these two movies because they're tied together by Star Wars, but at the end of the day, do we really want to base our recommendations on the behaviour of one or two people that watch some obscure movie?
#
# Probably not! I mean yes, the two people in the world, or whatever it is, that watch the movie Full Speed, and both liked it in addition to Star Wars, maybe that is a good recommendation for them, but it's probably not a good recommendation to the rest of the world. We need to have some sort of confidence level in our similarities by enforcing a minimum boundary of how many people watched a given movie. We can't make a judgement that a given movie is good just based on the behaviour of one or two people.
#
# So, let's try to put that insight into action using the following code.

# %%
import numpy as np
movieStats = ratings.groupby('title').agg({'rating':[np.size,np.mean]})
movieStats.head()
# Out:
#                           rating
#                             size      mean
# title
# 'Til There Was You (1997)      9  2.333333
# 1-900 (1994)                   5  2.600000
# 101 Dalmatians (1996)        109  2.908257
# 12 Angry Men (1957)          125  4.344000
# 187 (1997)                    41  3.024390

# %% [markdown]
# What we're going to do is try to identify the movies that weren't actually rated by many people and we'll just throw them out and see what we get. So, to do that we're going to take our original ratings DataFrame and we're going to say `groupby('title')`, again Pandas has all sorts of magic in it. And, this will basically construct a new DataFrame that aggregates together all the rows for a given title into one row.
#
# We can say that we want to aggregate specifically on the rating, and we want to show both the size, the number of ratings for each movie, and the mean average score, the mean rating for that movie. So, when we do that, we end up with something like the above.
#
# This is telling us, for example, for the movie `101 Dalmatians (1996)`, `109` people rated that movie and their average rating was 2.9 stars, so not that great of a score really! So, if we just eyeball this data, we can say okay well, movies that I consider obscure, like `187 (1997)`, had `41` ratings, but `101 Dalmatians (1996)`, I've heard of that, you know `12 Angry Men (1957)`, I've heard of that. It seems like there's sort of a natural cutoff value at around `100` ratings, where maybe that's the magic value where things start to make sense.
#
# Let's go ahead and get rid of movies rated by fewer than 100 people, and yes, you know I'm kind of doing this intuitively at this point. As we'll talk about later, there are more principled ways of doing this, where you could actually experiment and do train/test experiments on different threshold values, to find the one that actually performs the best. But initially, let's just use our common sense and filter out movies that were rated by fewer than 100 people. Again, Pandas makes that really easy to do.
#
# Let's figure it out with the following example:

# %%
#movieStats.loc['Star Wars (1977)']

popularMovies = movieStats['rating']['size']>=100
movieStats = movieStats[popularMovies].sort_values([('rating','mean')],ascending=False)
# movieStats = movieStats[movieStats.index != 'Star Wars (1977)']    #drop row having Star Wars(1977)
movieStats
# Out:
#                                                    rating
#                                                      size      mean
# title
# Close Shave, A (1995)                                 112  4.491071
# Schindler's List (1993)                               298  4.466443
# Wrong Trousers, The (1993)                            118  4.466102
# Casablanca (1942)                                     243  4.456790
# Shawshank Redemption, The (1994)                      283  4.445230
# Rear Window (1954)                                    209  4.387560
# Usual Suspects, The (1995)                            267  4.385768
# Star Wars (1977)                                      584  4.359589
# 12 Angry Men (1957)                                   125  4.344000
# Citizen Kane (1941)                                   198  4.292929
# To Kill a Mockingbird (1962)                          219  4.292237
# One Flew Over the Cuckoo's Nest (1975)                264  4.291667
# Silence of the Lambs, The (1991)                      390  4.289744
# North by Northwest (1959)                             179  4.284916
# Godfather, The (1972)                                 413  4.283293
# Secrets & Lies (1996)                                 162  4.265432
# Good Will Hunting (1997)                              198  4.262626
# Manchurian Candidate, The (1962)                      131  4.259542
# Dr. Strangelove or: How I Learned to Stop Worry...    194  4.252577
# Raiders of the Lost Ark (1981)                        420  4.252381
# Vertigo (1958)                                        179  4.251397
# Titanic (1997)                                        350  4.245714
# Lawrence of Arabia (1962)                             173  4.231214
# Maltese Falcon, The (1941)                            138  4.210145
# Empire Strikes Back, The (1980)                       368  4.206522
# Boot, Das (1981)                                      201  4.203980
# Sling Blade (1996)                                    136  4.198529
# As Good As It Gets (1997)                             112  4.196429
# Godfather: Part II, The (1974)                        209  4.186603
# African Queen, The (1951)                             152  4.184211
# Bridge on the River Kwai, The (1957)                  165  4.175758
# Cinema Paradiso (1988)                                121  4.173554
# Princess Bride, The (1987)                            324  4.172840
# Amadeus (1984)                                        276  4.163043
# L.A. Confidential (1997)                              297  4.161616
# Fargo (1996)                                          508  4.155512
# Braveheart (1995)                                     297  4.151515
# Blade Runner (1982)                                   275  4.138182
# Henry V (1989)                                        124  4.137097
# Chinatown (1974)                                      147  4.136054
# Killing Fields, The (1984)                            121  4.132231
# Mr. Smith Goes to Washington (1939)                   105  4.123810
# It's a Wonderful Life (1946)                          231  4.121212
# Taxi Driver (1976)                                    182  4.120879
# Raging Bull (1980)                                    116  4.120690
# Philadelphia Story, The (1940)                        104  4.115385
# Great Escape, The (1963)                              124  4.104839
# Graduate, The (1967)                                  239  4.104603
# Psycho (1960)                                         239  4.100418
# Apt Pupil (1998)                                      160  4.100000
# Hoop Dreams (1994)                                    117  4.094017
# Arsenic and Old Lace (1944)                           115  4.078261
# Wizard of Oz, The (1939)                              246  4.077236
# Glory (1989)                                          171  4.076023
# Monty Python and the Holy Grail (1974)                316  4.066456
# Much Ado About Nothing (1993)                         176  4.062500
# Pulp Fiction (1994)                                   394  4.060914
# Sting, The (1973)                                     241  4.058091
# Lone Star (1996)                                      187  4.053476
# Apocalypse Now (1979)                                 221  4.045249
# Fugitive, The (1993)                                  336  4.044643
# Alien (1979)                                          291  4.034364
# Strictly Ballroom (1992)                              104  4.028846
# Gandhi (1982)                                         195  4.020513
# Sense and Sensibility (1995)                          268  4.011194
# Return of the Jedi (1983)                             507  4.007890
# Nikita (La Femme Nikita) (1990)                       127  4.007874
# Terminator 2: Judgment Day (1991)                     295  4.006780
# Babe (1995)                                           219  3.995434
# Cool Hand Luke (1967)                                 164  3.993902
# Singin' in the Rain (1952)                            137  3.992701
# Patton (1970)                                         136  3.992647
# Kolya (1996)                                          117  3.991453
# Reservoir Dogs (1992)                                 148  3.986486
# Room with a View, A (1986)                            134  3.985075
# Some Like It Hot (1959)                               128  3.984375
# 2001: A Space Odyssey (1968)                          259  3.969112
# Postino, Il (1994)                                    183  3.967213
# GoodFellas (1990)                                     226  3.951327
# Butch Cassidy and the Sundance Kid (1969)             216  3.949074
# Aliens (1986)                                         284  3.947183
# Young Frankenstein (1974)                             200  3.945000
# Magnificent Seven, The (1954)                         121  3.942149
# Remains of the Day, The (1993)                        150  3.940000
# Terminator, The (1984)                                301  3.933555
# Apollo 13 (1995)                                      276  3.931159
# Indiana Jones and the Last Crusade (1989)             331  3.930514
# Full Monty, The (1997)                                315  3.926984
# Shine (1996)                                          129  3.922481
# Right Stuff, The (1983)                               157  3.917197
# Dead Poets Society (1989)                             251  3.916335
# M*A*S*H (1970)                                        206  3.912621
# In the Name of the Father (1993)                      102  3.911765
# Annie Hall (1977)                                     180  3.911111
# When Harry Met Sally... (1989)                        290  3.910345
# Clockwork Orange, A (1971)                            221  3.909502
# Searching for Bobby Fischer (1993)                    138  3.905797
# This Is Spinal Tap (1984)                             191  3.905759
# Being There (1979)                                    116  3.905172
# Big Night (1996)                                      171  3.900585
# Dead Man Walking (1995)                               299  3.896321
# Trainspotting (1996)                                  250  3.884000
# Stand by Me (1986)                                    227  3.881057
# Toy Story (1995)                                      452  3.878319
# Raising Arizona (1987)                                256  3.875000
# Die Hard (1988)                                       243  3.872428
# Unforgiven (1992)                                     182  3.868132
# Hunt for Red October, The (1990)                      227  3.863436
# Good, The Bad and The Ugly, The (1966)                137  3.861314
# Amistad (1997)                                        124  3.854839
# Gone with the Wind (1939)                             172  3.854651
# Philadelphia (1993)                                   137  3.854015
# Forrest Gump (1994)                                   321  3.853583
# My Left Foot (1989)                                   121  3.851240
# Seven (Se7en) (1995)                                  236  3.847458
# Chasing Amy (1997)                                    379  3.839050
# Blues Brothers, The (1980)                            251  3.836653
# Back to the Future (1985)                             350  3.834286
# E.T. the Extra-Terrestrial (1982)                     300  3.833333
# Deer Hunter, The (1978)                               120  3.833333
# Ben-Hur (1959)                                        124  3.830645
# Swingers (1996)                                       157  3.828025
# Shining, The (1980)                                   206  3.825243
# Cold Comfort Farm (1995)                              125  3.824000
# Bound (1996)                                          129  3.821705
# Bonnie and Clyde (1967)                               122  3.819672
# Harold and Maude (1971)                               121  3.818182
# Brazil (1985)                                         208  3.817308
# My Fair Lady (1964)                                   125  3.816000
# Star Trek: The Wrath of Khan (1982)                   244  3.815574
# Aladdin (1992)                                        219  3.812785
# Birds, The (1963)                                     162  3.808642
# Clerks (1994)                                         148  3.804054
# Like Water For Chocolate (Como agua para chocol...    148  3.804054
# Contact (1997)                                        509  3.803536
# Donnie Brasco (1997)                                  147  3.802721
# Twelve Monkeys (1995)                                 392  3.798469
# Dances with Wolves (1990)                             256  3.792969
# In the Line of Fire (1993)                            169  3.792899
# Beauty and the Beast (1991)                           202  3.792079
# Fish Called Wanda, A (1988)                           247  3.785425
# Lion King, The (1994)                                 220  3.781818
# Mr. Holland's Opus (1995)                             293  3.778157
# Jaws (1975)                                           280  3.775000
# Fantasia (1940)                                       174  3.770115
# Face/Off (1997)                                       194  3.768041
# Sound of Music, The (1965)                            222  3.765766
# Fried Green Tomatoes (1991)                           153  3.764706
# Groundhog Day (1993)                                  280  3.764286
# Ulee's Gold (1997)                                    184  3.760870
# Monty Python's Life of Brian (1979)                   174  3.747126
# Men in Black (1997)                                   303  3.745875
# Mary Poppins (1964)                                   178  3.724719
# Welcome to the Dollhouse (1995)                       112  3.723214
# Miracle on 34th Street (1994)                         101  3.722772
# Jurassic Park (1993)                                  261  3.720307
# Emma (1996)                                           177  3.717514
# Jerry Maguire (1996)                                  384  3.710938
# Snow White and the Seven Dwarfs (1937)                172  3.709302
# Professional, The (1994)                              149  3.704698
# Field of Dreams (1989)                                212  3.698113
# Leaving Las Vegas (1995)                              298  3.697987
# Rock, The (1996)                                      378  3.693122
# Platoon (1986)                                        127  3.692913
# Heathers (1989)                                       171  3.690058
# Time to Kill, A (1996)                                232  3.685345
# Full Metal Jacket (1987)                              170  3.682353
# Little Women (1994)                                   102  3.676471
# Grosse Pointe Blank (1997)                            160  3.675000
# Pinocchio (1940)                                      101  3.673267
# Rosewood (1997)                                       114  3.666667
# Tombstone (1993)                                      108  3.666667
# Real Genius (1985)                                    119  3.663866
# Four Weddings and a Funeral (1994)                    251  3.661355
# Star Trek: First Contact (1996)                       365  3.660274
# English Patient, The (1996)                           481  3.656965
# Dave (1993)                                           180  3.650000
# Speed (1994)                                          230  3.647826
# Quiz Show (1994)                                      175  3.645714
# Ransom (1996)                                         267  3.644195
# Jackie Brown (1997)                                   126  3.642857
# Willy Wonka and the Chocolate Factory (1971)          326  3.631902
# Air Force One (1997)                                  431  3.631090
# Crimson Tide (1995)                                   154  3.629870
# American President, The (1995)                        164  3.628049
# Crying Game, The (1992)                               119  3.621849
# True Romance (1993)                                   104  3.615385
# Ice Storm, The (1997)                                 108  3.611111
# Courage Under Fire (1996)                             221  3.610860
# Ed Wood (1994)                                        133  3.601504
# Piano, The (1993)                                     168  3.601190
# Primal Fear (1996)                                    178  3.601124
# Rainmaker, The (1997)                                 145  3.600000
# Fly Away Home (1996)                                  180  3.600000
# Gattaca (1997)                                        136  3.595588
# People vs. Larry Flynt, The (1996)                    215  3.595349
# Adventures of Priscilla, Queen of the Desert, T...    111  3.594595
# William Shakespeare's Romeo and Juliet (1996)         106  3.594340
# Game, The (1997)                                      251  3.593625
# Abyss, The (1989)                                     151  3.589404
# Nightmare Before Christmas, The (1993)                143  3.587413
# Boogie Nights (1997)                                  189  3.587302
# Cinderella (1950)                                     129  3.581395
# Clear and Present Danger (1994)                       179  3.569832
# Heat (1995)                                           223  3.569507
# True Lies (1994)                                      208  3.562500
# Phenomenon (1996)                                     244  3.557377
# On Golden Pond (1981)                                 106  3.556604
# Hudsucker Proxy, The (1994)                           110  3.554545
# Get Shorty (1995)                                     209  3.550239
# Muriel's Wedding (1994)                               100  3.550000
# While You Were Sleeping (1995)                        162  3.549383
# Last of the Mohicans, The (1992)                      128  3.546875
# Sleepless in Seattle (1993)                           213  3.539906
# Edge, The (1997)                                      113  3.539823
# What's Eating Gilbert Grape (1993)                    115  3.539130
# Highlander (1986)                                     153  3.535948
# Private Parts (1997)                                  100  3.530000
# Devil's Advocate, The (1997)                          188  3.515957
# Sleepers (1996)                                       169  3.514793
# Sneakers (1992)                                       150  3.513333
# Wag the Dog (1997)                                    137  3.510949
# Carrie (1976)                                         121  3.504132
# Sabrina (1995)                                        190  3.500000
# Dumbo (1941)                                          123  3.495935
# Truth About Cats & Dogs, The (1996)                   272  3.485294
# Top Gun (1986)                                        220  3.481818
# Fifth Element, The (1997)                             197  3.477157
# Sex, Lies, and Videotape (1989)                       101  3.475248
# Long Kiss Goodnight, The (1996)                       185  3.470270
# Maverick (1994)                                       128  3.468750
# That Thing You Do! (1996)                             176  3.465909
# Ghost (1990)                                          170  3.464706
# Kiss the Girls (1997)                                 143  3.461538
# Benny & Joon (1993)                                   102  3.460784
# Con Air (1997)                                        137  3.459854
# Clueless (1995)                                       170  3.458824
# Seven Years in Tibet (1997)                           155  3.458065
# Cape Fear (1991)                                      171  3.456140
# Rumble in the Bronx (1995)                            174  3.448276
# Star Trek IV: The Voyage Home (1986)                  199  3.447236
# Birdcage, The (1996)                                  293  3.443686
# Scream (1996)                                         478  3.441423
# Independence Day (ID4) (1996)                         429  3.438228
# Army of Darkness (1993)                               116  3.431034
# Mystery Science Theater 3000: The Movie (1996)        130  3.430769
# Batman (1989)                                         201  3.427861
# Tomorrow Never Dies (1997)                            180  3.427778
# Conspiracy Theory (1997)                              295  3.423729
# Mighty Aphrodite (1995)                               184  3.418478
# Crow, The (1994)                                      134  3.417910
# Mrs. Doubtfire (1993)                                 192  3.411458
# Beautiful Girls (1996)                                115  3.391304
# Happy Gilmore (1996)                                  149  3.389262
# Hunchback of Notre Dame, The (1996)                   127  3.377953
# Cop Land (1997)                                       175  3.377143
# Absolute Power (1997)                                 127  3.370079
# My Best Friend's Wedding (1997)                       172  3.360465
# G.I. Jane (1997)                                      175  3.360000
# Executive Decision (1996)                             157  3.356688
# Die Hard 2 (1990)                                     166  3.355422
# Pink Floyd - The Wall (1982)                          114  3.350877
# Grease (1978)                                         170  3.347059
# Star Trek: Generations (1994)                         116  3.336207
# Pretty Woman (1990)                                   164  3.323171
# Michael (1996)                                        119  3.319328
# Mission: Impossible (1996)                            344  3.313953
# In & Out (1997)                                       230  3.304348
# Under Siege (1992)                                    124  3.290323
# Die Hard: With a Vengeance (1995)                     151  3.284768
# Star Trek VI: The Undiscovered Country (1991)         161  3.279503
# Firm, The (1993)                                      151  3.278146
# Everyone Says I Love You (1996)                       168  3.273810
# Peacemaker, The (1997)                                136  3.272059
# Jackie Chan's First Strike (1996)                     145  3.255172
# Austin Powers: International Man of Mystery (1997)    130  3.246154
# Outbreak (1995)                                       104  3.240385
# Frighteners, The (1996)                               115  3.234783
# Starship Troopers (1997)                              211  3.232227
# One Fine Day (1996)                                   112  3.232143
# Basic Instinct (1992)                                 101  3.227723
# Scream 2 (1997)                                       106  3.216981
# Twister (1996)                                        293  3.215017
# Young Guns (1988)                                     101  3.207921
# GoldenEye (1995)                                      131  3.206107
# Ghost and the Darkness, The (1996)                    128  3.203125
# Mask, The (1994)                                      129  3.193798
# Interview with the Vampire (1994)                     137  3.182482
# Nightmare on Elm Street, A (1984)                     111  3.171171
# Tin Cup (1996)                                        193  3.160622
# Bram Stoker's Dracula (1992)                          120  3.158333
# Liar Liar (1997)                                      485  3.156701
# Eraser (1996)                                         206  3.150485
# River Wild, The (1994)                                146  3.143836
# Stargate (1994)                                       127  3.141732
# Lost Highway (1997)                                   125  3.136000
# Mother (1996)                                         169  3.130178
# Kingpin (1996)                                        162  3.129630
# James and the Giant Peach (1996)                      126  3.126984
# Saint, The (1997)                                     316  3.123418
# Craft, The (1996)                                     104  3.115385
# Star Trek III: The Search for Spock (1984)            171  3.111111
# Devil's Own, The (1997)                               240  3.108333
# Alien: Resurrection (1997)                            124  3.096774
# Home Alone (1990)                                     137  3.087591
# Murder at 1600 (1997)                                 218  3.087156
# Dragonheart (1996)                                    158  3.082278
# I Know What You Did Last Summer (1997)                100  3.060000
# Ace Ventura: Pet Detective (1994)                     103  3.048544
# Conan the Barbarian (1981)                            107  3.046729
# Grumpier Old Men (1995)                               148  3.040541
# Star Trek: The Motion Picture (1979)                  117  3.034188
# Broken Arrow (1996)                                   254  3.031496
# First Wives Club, The (1996)                          160  3.018750
# Net, The (1995)                                       120  3.008333
# Evita (1996)                                          259  2.980695
# Natural Born Killers (1994)                           128  2.953125
# Lost World: Jurassic Park, The (1997)                 158  2.943038
# Dante's Peak (1997)                                   240  2.933333
# Nutty Professor, The (1996)                           163  2.914110
# 101 Dalmatians (1996)                                 109  2.908257
# Father of the Bride Part II (1995)                    128  2.898438
# Mars Attacks! (1996)                                  217  2.847926
# Multiplicity (1996)                                   134  2.835821
# Alien 3 (1992)                                        100  2.830000
# Volcano (1997)                                        219  2.808219
# Waterworld (1995)                                     102  2.803922
# Beavis and Butt-head Do America (1996)                156  2.788462
# Mimic (1997)                                          101  2.742574
# Down Periscope (1996)                                 101  2.702970
# George of the Jungle (1997)                           162  2.685185
# Batman Returns (1992)                                 142  2.683099
# Batman Forever (1995)                                 114  2.666667
# Spawn (1997)                                          143  2.615385
# Event Horizon (1997)                                  127  2.574803
# Crash (1996)                                          128  2.546875
# Jungle2Jungle (1997)                                  132  2.439394
# Cable Guy, The (1996)                                 106  2.339623

# %% [markdown]
#
# What we have here is a list of movies that were rated by more than 100 people, sorted by their average rating score, and this in itself is a recommender system. These are highly-rated popular movies. A `Close Shave (1995)`, apparently, was a really good movie and a lot of people watched it and they really liked it.
#
# So again, this is a very old dataset, from the late 90s, so even though you might not be familiar with the film A `Close Shave (1995)`, it might be worth going back and rediscovering it; add it to your Netflix! `Schindler's List (1993)` not a big surprise there, that comes up on the top of most top movies lists. The `Wrong Trousers (1993)`, another example of an obscure film that apparently was really good and was also pretty popular. So, some interesting discoveries there already, just by doing that.
#
# Things look a little bit better now, so let's go ahead and basically make our new DataFrame of Star Wars recommendations, movies similar to Star Wars, where we only base it on movies that appear in this new DataFrame. So, we're going to use the `join` operation, to go ahead and join our original `similarMovies` DataFrame to this new DataFrame of only movies that have greater than 100 ratings, okay?

# %%
df = movieStats.join(pd.DataFrame(similarMovies,columns=['similarity']))
df.head()
# Out:
#                                   (rating, size)  (rating, mean)  similarity
# title
# Close Shave, A (1995)                        112        4.491071    0.183451
# Schindler's List (1993)                      298        4.466443    0.100933
# Wrong Trousers, The (1993)                   118        4.466102    0.216204
# Casablanca (1942)                            243        4.456790    0.248016
# Shawshank Redemption, The (1994)             283        4.445230    0.174986

# %% [markdown]
# In this code, we create a new DataFrame based on similarMovies where we extract the similarity column, join that with our movieStats DataFrame, which is our popularMovies DataFrame, and we look at the combined results. And, there we go with that output!
#
# Now we have, restricted only to movies that are rated by more than 100 people, the similarity score to Star Wars. So, now all we need to do is sort that using the following code:

# %%
df.sort_values(['similarity'],ascending=False)[:15]
# Out:
#                                                     (rating, size)  \
# title
# Star Wars (1977)                                               584
# Empire Strikes Back, The (1980)                                368
# Return of the Jedi (1983)                                      507
# Raiders of the Lost Ark (1981)                                 420
# Austin Powers: International Man of Mystery (1997)             130
# Sting, The (1973)                                              241
# Indiana Jones and the Last Crusade (1989)                      331
# Pinocchio (1940)                                               101
# Frighteners, The (1996)                                        115
# L.A. Confidential (1997)                                       297
# Wag the Dog (1997)                                             137
# Dumbo (1941)                                                   123
# Bridge on the River Kwai, The (1957)                           165
# Philadelphia Story, The (1940)                                 104
# Miracle on 34th Street (1994)                                  101
#
#                                                     (rating, mean)  similarity
# title
# Star Wars (1977)                                          4.359589    1.000000
# Empire Strikes Back, The (1980)                           4.206522    0.748353
# Return of the Jedi (1983)                                 4.007890    0.672556
# Raiders of the Lost Ark (1981)                            4.252381    0.536117
# Austin Powers: International Man of Mystery (1997)        3.246154    0.377433
# Sting, The (1973)                                         4.058091    0.367538
# Indiana Jones and the Last Crusade (1989)                 3.930514    0.350107
# Pinocchio (1940)                                          3.673267    0.347868
# Frighteners, The (1996)                                   3.234783    0.332729
# L.A. Confidential (1997)                                  4.161616    0.319065
# Wag the Dog (1997)                                        3.510949    0.318645
# Dumbo (1941)                                              3.495935    0.317656
# Bridge on the River Kwai, The (1957)                      4.175758    0.316580
# Philadelphia Story, The (1940)                            4.115385    0.314272
# Miracle on 34th Street (1994)                             3.722772    0.310921

# %% [markdown]
#
# This is starting to look a little bit better! So, `Star Wars (1977)` comes out on top because it's similar to itself, The `Empire Strikes Back (1980)` is number 2, `Return of the Jedi (1983)` is number 3, `Raiders of the Lost Ark (1981)`, number 4. You know, it's still not perfect, but these make a lot more sense, right? So, you would expect the three Star Wars films from the original trilogy to be similar to each other, this data goes back to before the next three films, and `Raiders of the Lost Ark (1981)` is also a very similar movie to Star Wars in style, and it comes out as number 4. So, I'm starting to feel a little bit better about these results. There's still room for improvement, but hey! We got some results that make sense, whoo-hoo!

# %% [markdown]
# Now, ideally, we'd also filter out Star Wars, you don't want to be looking at similarities to the movie itself that you started from, but we'll worry about that later! So, if you want to play with this a little bit more, like I said 100 was sort of an arbitrary cutoff for the minimum number of ratings. If you do want to experiment with different cutoff values, I encourage you to go back and do so. See what that does to the results. You know, you can see in the preceding table that the results that we really like actually had much more than 100 ratings in common. So, we end up with `Austin Powers: International Man of Mystery (1997)` coming in there pretty high with only 130 ratings so maybe 100 isn't high enough! `Pinocchio (1940)` snuck in at 101, not very similar to Star Wars, so, you might want to consider an even higher threshold there and see what it does.

# %% [markdown]
# **Note:** Please keep in mind too, this is a very small, limited dataset that we used for experimentation purposes, and it's based on very old data, so you're only going to    see older movies. So, interpreting these results intuitively might be a little bit challenging as a result, but not bad results

# %%
k = movieStats.index is not 'Star Wars (1977)'
k
# Out:
# True

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
movieStats.loc['Miracle on 34th Street (1994)']
# Out:
# rating  size    101.000000
#         mean      3.722772
# Name: Miracle on 34th Street (1994), dtype: float64

# %% [markdown]
# ## Understanding movie recommendation with an example

# %% [markdown]
# So, what we do with this data? Well, what we want to do is recommend movies for people. The way we do that is we look at all the ratings for a given person, find movies similar to the stuff that they rated, and those are candidates for recommendations to that person.
#
# Let's start by creating a fake person to create recommendations for. I've actually already added a fake user by hand, ID number 0, to the MovieLens dataset that we're processing. You can see that user with the following code:

# %%
myRatings = movieRatings.loc[0].dropna()
myRatings
# Out:
#         title
# rating  Empire Strikes Back, The (1980)    5.0
#         Gone with the Wind (1939)          1.0
#         Star Wars (1977)                   5.0
# Name: 0, dtype: float64

# %% [markdown]
# That kind of represents someone like me, who loved Star Wars and The Empire Strikes Back, but hated the movie Gone with the Wind. So, this represents someone who really loves Star Wars, but does not like old style, romantic dramas, okay? So, I gave a rating of 5 star to `The Empire Strikes Back (1980)` and `Star Wars (1977)`, and a rating of 1 star to `Gone with the Wind (1939)`. So, I'm going to try to find recommendations for this fictitious user. So, how do I do that? Well, let's start by creating a series called simCandidates and I'm going to go through every movie that I rated.

# %%
simCandidates = pd.Series()
for i in range(0,len(myRatings.index)):
    print("Adding sims for ",myRatings.index[i],"...")
    sims = corrMatrix[myRatings.index[i]].dropna()
    sims = sims.map(lambda x: x*myRatings[i])
    print(sims)
    simCandidates = simCandidates.append(sims)

print('\nsorting..\n')
simCandidates.sort_values(inplace=True,ascending=False)
print(simCandidates.head(10))
# Out:
# Adding sims for  ('rating', 'Empire Strikes Back, The (1980)') ...
#         title
# rating  2001: A Space Odyssey (1968)                                                   0.707991
#         Abyss, The (1989)                                                              1.389334
#         African Queen, The (1951)                                                      1.158286
#         Air Force One (1997)                                                           0.828101
#         Aladdin (1992)                                                                 1.555313
#         Alien (1979)                                                                   1.008343
#         Aliens (1986)                                                                  1.462883
#         Amadeus (1984)                                                                 0.746641
#         American President, The (1995)                                                 1.065284
#         Annie Hall (1977)                                                             -0.011175
#         Apocalypse Now (1979)                                                          0.420130
#         Apollo 13 (1995)                                                               0.984504
#         Babe (1995)                                                                    0.546663
#         Back to the Future (1985)                                                      1.726427
#         Batman (1989)                                                                  1.500844
#         Batman Forever (1995)                                                          0.560036
#         Batman Returns (1992)                                                          0.667613
#         Beauty and the Beast (1991)                                                    0.786928
#         Ben-Hur (1959)                                                                 1.052943
#         Birdcage, The (1996)                                                           0.460942
#         Birds, The (1963)                                                              0.336964
#         Blade Runner (1982)                                                            0.968956
#         Blues Brothers, The (1980)                                                     1.098828
#         Boot, Das (1981)                                                               0.821577
#         Bram Stoker's Dracula (1992)                                                   0.713597
#         Braveheart (1995)                                                              1.285368
#         Brazil (1985)                                                                 -0.445548
#         Bridge on the River Kwai, The (1957)                                           1.783717
#         Broken Arrow (1996)                                                            0.968547
#         Butch Cassidy and the Sundance Kid (1969)                                      1.223255
#         Cape Fear (1991)                                                               0.554136
#         Casablanca (1942)                                                              1.352254
#         Chasing Amy (1997)                                                             1.633938
#         Chinatown (1974)                                                               0.623258
#         Cinderella (1950)                                                              1.749598
#         Citizen Kane (1941)                                                            0.587702
#         Clear and Present Danger (1994)                                                0.304322
#         Clerks (1994)                                                                  0.505023
#         Clockwork Orange, A (1971)                                                     0.290754
#         Clueless (1995)                                                               -0.183557
#         Conan the Barbarian (1981)                                                     0.159260
#         Contact (1997)                                                                 0.831848
#         Cool Hand Luke (1967)                                                          0.406579
#         Courage Under Fire (1996)                                                     -0.269817
#         Crimson Tide (1995)                                                            0.821421
#         Crow, The (1994)                                                               0.776048
#         Dances with Wolves (1990)                                                      0.799106
#         Dave (1993)                                                                    1.465644
#         Dead Man Walking (1995)                                                        0.020183
#         Dead Poets Society (1989)                                                      0.657927
#         Die Hard (1988)                                                                1.218708
#         Die Hard 2 (1990)                                                              0.765167
#         Die Hard: With a Vengeance (1995)                                              1.183048
#         Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)    0.494029
#         Dragonheart (1996)                                                             0.887015
#         Dumbo (1941)                                                                   1.393364
#         E.T. the Extra-Terrestrial (1982)                                              1.092687
#         Ed Wood (1994)                                                                 0.377578
#         Empire Strikes Back, The (1980)                                                5.000000
#         English Patient, The (1996)                                                   -0.021403
#         Eraser (1996)                                                                  0.360990
#         Fantasia (1940)                                                                0.478439
#         Fargo (1996)                                                                   0.224829
#         Field of Dreams (1989)                                                         1.642076
#         Fifth Element, The (1997)                                                      0.553421
#         Firm, The (1993)                                                               1.379816
#         Fish Called Wanda, A (1988)                                                    0.895910
#         Forrest Gump (1994)                                                            1.119778
#         Four Weddings and a Funeral (1994)                                             0.474709
#         Fried Green Tomatoes (1991)                                                    0.175220
#         Fugitive, The (1993)                                                           1.214360
#         Full Metal Jacket (1987)                                                       0.299080
#         Full Monty, The (1997)                                                         0.237915
#         Gandhi (1982)                                                                  0.749788
#         Get Shorty (1995)                                                              1.189489
#         Ghost (1990)                                                                   0.630393
#         Glory (1989)                                                                   1.217792
#         Godfather, The (1972)                                                          0.745604
#         Godfather: Part II, The (1974)                                                 1.042651
#         GoldenEye (1995)                                                               0.956269
#         Gone with the Wind (1939)                                                      0.678435
#         Good, The Bad and The Ugly, The (1966)                                         0.606749
#         GoodFellas (1990)                                                              0.963081
#         Graduate, The (1967)                                                           0.540867
#         Grease (1978)                                                                  1.191911
#         Groundhog Day (1993)                                                           1.314372
#         Heat (1995)                                                                    0.830191
#         Heathers (1989)                                                                0.392888
#         Highlander (1986)                                                              0.204670
#         Home Alone (1990)                                                              0.739794
#         Hunt for Red October, The (1990)                                               0.893746
#         In the Line of Fire (1993)                                                     0.446323
#         Independence Day (ID4) (1996)                                                  0.852012
#         Indiana Jones and the Last Crusade (1989)                                      1.566182
#         Interview with the Vampire (1994)                                              0.807728
#         It's a Wonderful Life (1946)                                                   1.116185
#         Jaws (1975)                                                                    1.475638
#         Jerry Maguire (1996)                                                           0.772526
#         Jurassic Park (1993)                                                           1.264471
#         L.A. Confidential (1997)                                                       1.104627
#         Last of the Mohicans, The (1992)                                               0.209693
#         Lawrence of Arabia (1962)                                                      1.129174
#         Leaving Las Vegas (1995)                                                       0.829914
#         Liar Liar (1997)                                                               1.161289
#         Lion King, The (1994)                                                          1.452646
#         Long Kiss Goodnight, The (1996)                                                0.439786
#         M*A*S*H (1970)                                                                 0.889486
#         Maltese Falcon, The (1941)                                                     0.705572
#         Mars Attacks! (1996)                                                           0.121396
#         Mary Poppins (1964)                                                            0.748073
#         Mask, The (1994)                                                               1.039459
#         Maverick (1994)                                                                0.697558
#         Men in Black (1997)                                                            1.247213
#         Mission: Impossible (1996)                                                     0.974224
#         Monty Python and the Holy Grail (1974)                                         0.945723
#         Monty Python's Life of Brian (1979)                                            0.860460
#         Mr. Holland's Opus (1995)                                                      0.588756
#         Mrs. Doubtfire (1993)                                                          1.086945
#         Much Ado About Nothing (1993)                                                  0.220816
#         Natural Born Killers (1994)                                                    0.733071
#         Net, The (1995)                                                                0.965656
#         Nightmare Before Christmas, The (1993)                                        -0.017810
#         North by Northwest (1959)                                                      0.896113
#         Nutty Professor, The (1996)                                                    1.056787
#         One Flew Over the Cuckoo's Nest (1975)                                         0.845954
#         Patton (1970)                                                                  0.666358
#         Phenomenon (1996)                                                              0.964499
#         Philadelphia (1993)                                                            0.687997
#         Piano, The (1993)                                                             -0.751857
#         Platoon (1986)                                                                 0.752679
#         Pretty Woman (1990)                                                            1.286209
#         Princess Bride, The (1987)                                                     1.431410
#         Professional, The (1994)                                                       0.703639
#         Psycho (1960)                                                                  0.818248
#         Pulp Fiction (1994)                                                            0.121311
#         Quiz Show (1994)                                                               1.028843
#         Raiders of the Lost Ark (1981)                                                 2.693297
#         Raising Arizona (1987)                                                         0.112648
#         Ransom (1996)                                                                  0.634629
#         Real Genius (1985)                                                            -0.072344
#         Rear Window (1954)                                                             0.277973
#         Reservoir Dogs (1992)                                                          0.436041
#         Return of the Jedi (1983)                                                      3.606146
#         Right Stuff, The (1983)                                                        0.688354
#         Rock, The (1996)                                                               0.665562
#         Rumble in the Bronx (1995)                                                    -0.119453
#         Sabrina (1995)                                                                 0.729951
#         Saint, The (1997)                                                              0.474534
#         Schindler's List (1993)                                                        0.521499
#         Scream (1996)                                                                  0.764208
#         Searching for Bobby Fischer (1993)                                             0.612944
#         Sense and Sensibility (1995)                                                   0.284878
#         Seven (Se7en) (1995)                                                           0.517121
#         Shawshank Redemption, The (1994)                                               0.976666
#         Shining, The (1980)                                                            0.546517
#         Silence of the Lambs, The (1991)                                               0.580309
#         Singin' in the Rain (1952)                                                     1.312500
#         Sleepless in Seattle (1993)                                                    1.242358
#         Sneakers (1992)                                                                1.074054
#         Snow White and the Seven Dwarfs (1937)                                         1.174277
#         Sound of Music, The (1965)                                                     0.625636
#         Speed (1994)                                                                   0.652995
#         Stand by Me (1986)                                                             0.510019
#         Star Trek III: The Search for Spock (1984)                                     1.283631
#         Star Trek IV: The Voyage Home (1986)                                           1.066131
#         Star Trek VI: The Undiscovered Country (1991)                                  0.888980
#         Star Trek: First Contact (1996)                                                1.396387
#         Star Trek: Generations (1994)                                                  1.513175
#         Star Trek: The Motion Picture (1979)                                           0.901715
#         Star Trek: The Wrath of Khan (1982)                                            1.557051
#         Star Wars (1977)                                                               3.741763
#         Stargate (1994)                                                                0.500211
#         Sting, The (1973)                                                              1.371935
#         Taxi Driver (1976)                                                             0.576529
#         Terminator 2: Judgment Day (1991)                                              1.667662
#         Terminator, The (1984)                                                         1.403832
#         This Is Spinal Tap (1984)                                                     -0.232496
#         Time to Kill, A (1996)                                                         0.096919
#         Tin Cup (1996)                                                                 1.026788
#         Titanic (1997)                                                                 0.922697
#         To Kill a Mockingbird (1962)                                                   0.486340
#         Top Gun (1986)                                                                 0.810515
#         Toy Story (1995)                                                               1.161774
#         Trainspotting (1996)                                                           0.256529
#         True Lies (1994)                                                               1.233488
#         Truth About Cats & Dogs, The (1996)                                            0.478884
#         Twelve Monkeys (1995)                                                          0.579873
#         Twister (1996)                                                                -0.051181
#         Under Siege (1992)                                                             0.696277
#         Unforgiven (1992)                                                              0.723529
#         Usual Suspects, The (1995)                                                     1.040460
#         Vertigo (1958)                                                                 0.703719
#         When Harry Met Sally... (1989)                                                 0.771111
#         While You Were Sleeping (1995)                                                 1.332783
#         Willy Wonka and the Chocolate Factory (1971)                                   0.958848
#         Wizard of Oz, The (1939)                                                       1.438373
#         Young Frankenstein (1974)                                                      0.929436
# Name: (rating, Empire Strikes Back, The (1980)), dtype: float64
# Adding sims for  ('rating', 'Gone with the Wind (1939)') ...
#         title
# rating  2001: A Space Odyssey (1968)                    0.004890
#         Alien (1979)                                   -0.057730
#         Aliens (1986)                                   0.056156
#         Amadeus (1984)                                  0.323631
#         Apollo 13 (1995)                                0.030318
#         Back to the Future (1985)                       0.257319
#         Blade Runner (1982)                             0.048333
#         Blues Brothers, The (1980)                      0.124627
#         Braveheart (1995)                               0.121169
#         Casablanca (1942)                               0.291137
#         Dances with Wolves (1990)                       0.140462
#         Dead Poets Society (1989)                       0.139189
#         E.T. the Extra-Terrestrial (1982)               0.361463
#         Empire Strikes Back, The (1980)                 0.135687
#         Fargo (1996)                                    0.124841
#         Field of Dreams (1989)                          0.153802
#         Fish Called Wanda, A (1988)                    -0.006385
#         Forrest Gump (1994)                             0.095262
#         Fugitive, The (1993)                           -0.017365
#         Godfather, The (1972)                           0.065994
#         Gone with the Wind (1939)                       1.000000
#         Graduate, The (1967)                            0.326215
#         Groundhog Day (1993)                            0.079423
#         Independence Day (ID4) (1996)                   0.180982
#         Indiana Jones and the Last Crusade (1989)       0.171311
#         It's a Wonderful Life (1946)                    0.305688
#         Jaws (1975)                                     0.133886
#         Jurassic Park (1993)                            0.138319
#         Lion King, The (1994)                           0.185623
#         M*A*S*H (1970)                                  0.313956
#         Mary Poppins (1964)                             0.244310
#         Monty Python and the Holy Grail (1974)          0.180938
#         One Flew Over the Cuckoo's Nest (1975)          0.072976
#         Princess Bride, The (1987)                     -0.012742
#         Psycho (1960)                                   0.193419
#         Pulp Fiction (1994)                             0.034826
#         Raiders of the Lost Ark (1981)                  0.145818
#         Raising Arizona (1987)                         -0.160481
#         Return of the Jedi (1983)                       0.209247
#         Schindler's List (1993)                         0.344765
#         Silence of the Lambs, The (1991)                0.032078
#         Sound of Music, The (1965)                      0.244235
#         Star Wars (1977)                                0.129207
#         Sting, The (1973)                               0.120216
#         Terminator 2: Judgment Day (1991)               0.133215
#         Terminator, The (1984)                          0.066005
#         Toy Story (1995)                                0.199741
#         When Harry Met Sally... (1989)                  0.197863
#         Willy Wonka and the Chocolate Factory (1971)    0.053934
#         Wizard of Oz, The (1939)                        0.430219
# Name: (rating, Gone with the Wind (1939)), dtype: float64
# Adding sims for  ('rating', 'Star Wars (1977)') ...
#         title
# rating  12 Angry Men (1957)                                                            0.921447
#         2001: A Space Odyssey (1968)                                                   1.154421
#         Absolute Power (1997)                                                          0.427199
#         Abyss, The (1989)                                                              1.018543
#         African Queen, The (1951)                                                      1.152701
#         Air Force One (1997)                                                           0.565821
#         Aladdin (1992)                                                                 0.958104
#         Alien (1979)                                                                   1.244953
#         Aliens (1986)                                                                  1.272219
#         Amadeus (1984)                                                                 0.951402
#         American President, The (1995)                                                 0.565945
#         Annie Hall (1977)                                                             -0.500600
#         Apocalypse Now (1979)                                                          0.142879
#         Apollo 13 (1995)                                                               1.110031
#         Army of Darkness (1993)                                                        0.519211
#         Austin Powers: International Man of Mystery (1997)                             1.887164
#         Babe (1995)                                                                    0.922560
#         Back to the Future (1985)                                                      1.374196
#         Batman (1989)                                                                  1.446722
#         Batman Forever (1995)                                                          0.568333
#         Batman Returns (1992)                                                          0.298456
#         Beauty and the Beast (1991)                                                    0.530995
#         Beavis and Butt-head Do America (1996)                                         0.664713
#         Ben-Hur (1959)                                                                 0.217766
#         Big Night (1996)                                                               0.761795
#         Birdcage, The (1996)                                                           0.302719
#         Birds, The (1963)                                                              0.418693
#         Blade Runner (1982)                                                            0.983575
#         Blues Brothers, The (1980)                                                     0.962802
#         Bonnie and Clyde (1967)                                                        0.423907
#         Boot, Das (1981)                                                               0.574286
#         Bound (1996)                                                                   0.449956
#         Bram Stoker's Dracula (1992)                                                   0.941844
#         Braveheart (1995)                                                              0.920790
#         Brazil (1985)                                                                 -0.053647
#         Bridge on the River Kwai, The (1957)                                           1.582899
#         Broken Arrow (1996)                                                            0.873296
#         Butch Cassidy and the Sundance Kid (1969)                                      1.021377
#         Cape Fear (1991)                                                               0.006855
#         Carrie (1976)                                                                 -0.141883
#         Casablanca (1942)                                                              1.240080
#         Chasing Amy (1997)                                                             0.372680
#         Chinatown (1974)                                                               0.393532
#         Cinderella (1950)                                                              1.495814
#         Citizen Kane (1941)                                                            0.391251
#         Clear and Present Danger (1994)                                               -0.109270
#         Clerks (1994)                                                                  0.097116
#         Clockwork Orange, A (1971)                                                     0.500874
#         Clueless (1995)                                                               -0.092362
#         Con Air (1997)                                                                 1.208523
#         Conan the Barbarian (1981)                                                     0.007744
#         Conspiracy Theory (1997)                                                       0.528791
#         Contact (1997)                                                                 0.674810
#         Cool Hand Luke (1967)                                                          1.062749
#         Courage Under Fire (1996)                                                      0.232415
#         Crimson Tide (1995)                                                            0.655291
#         Crow, The (1994)                                                               1.140523
#         Crying Game, The (1992)                                                        0.349070
#         Dances with Wolves (1990)                                                      0.407631
#         Dante's Peak (1997)                                                            0.050516
#         Dave (1993)                                                                    0.819437
#         Dead Man Walking (1995)                                                       -0.170791
#         Dead Poets Society (1989)                                                      0.393993
#         Deer Hunter, The (1978)                                                        0.157361
#         Devil's Own, The (1997)                                                        0.246792
#         Die Hard (1988)                                                                0.682476
#         Die Hard 2 (1990)                                                              0.730656
#         Die Hard: With a Vengeance (1995)                                              1.070171
#         Donnie Brasco (1997)                                                           0.845508
#         Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)    0.134606
#         Dragonheart (1996)                                                             0.816670
#         Dumbo (1941)                                                                   1.588281
#         E.T. the Extra-Terrestrial (1982)                                              1.518097
#         Ed Wood (1994)                                                                 0.132727
#         Emma (1996)                                                                    0.270056
#         Empire Strikes Back, The (1980)                                                3.741763
#         English Patient, The (1996)                                                    0.245064
#         Eraser (1996)                                                                  0.565284
#         Evita (1996)                                                                   0.377304
#         Executive Decision (1996)                                                      0.269410
#         Face/Off (1997)                                                                0.056856
#         Fantasia (1940)                                                                0.524184
#         Fargo (1996)                                                                   0.222073
#         Father of the Bride Part II (1995)                                            -0.106624
#         Field of Dreams (1989)                                                         1.426432
#         Fifth Element, The (1997)                                                      0.706514
#         Firm, The (1993)                                                               1.329390
#         First Wives Club, The (1996)                                                  -0.972480
#         Fish Called Wanda, A (1988)                                                    1.047319
#         Forrest Gump (1994)                                                            0.797045
#         Four Weddings and a Funeral (1994)                                             0.048273
#         Fried Green Tomatoes (1991)                                                    0.262929
#         Frighteners, The (1996)                                                        1.663647
#         Fugitive, The (1993)                                                           0.807628
#         Full Metal Jacket (1987)                                                       0.210705
#         Full Monty, The (1997)                                                         0.301080
#         Game, The (1997)                                                               0.359152
#         Gandhi (1982)                                                                  0.876067
#         Get Shorty (1995)                                                              1.295912
#         Ghost (1990)                                                                   0.553065
#         Ghost and the Darkness, The (1996)                                             1.105615
#         Glory (1989)                                                                   1.096130
#         Godfather, The (1972)                                                          0.948875
#         Godfather: Part II, The (1974)                                                 0.727729
#         GoldenEye (1995)                                                               0.656741
#         Gone with the Wind (1939)                                                      0.646037
#         Good Will Hunting (1997)                                                       0.547781
#         Good, The Bad and The Ugly, The (1966)                                         0.230365
#         GoodFellas (1990)                                                              0.549472
#         Graduate, The (1967)                                                           0.080042
#         Grease (1978)                                                                  1.137759
#         Great Escape, The (1963)                                                       0.777351
#         Grosse Pointe Blank (1997)                                                     0.790269
#         Groundhog Day (1993)                                                           0.664434
#         Grumpier Old Men (1995)                                                        0.206574
#         Happy Gilmore (1996)                                                           0.566897
#         Harold and Maude (1971)                                                        0.831560
#         Heat (1995)                                                                    0.187633
#         Heathers (1989)                                                                0.080557
#         Henry V (1989)                                                                -0.244385
#         Highlander (1986)                                                              0.774412
#         Home Alone (1990)                                                              0.231138
#         Hoop Dreams (1994)                                                             0.244577
#         Hudsucker Proxy, The (1994)                                                    0.814825
#         Hunchback of Notre Dame, The (1996)                                            0.447874
#         Hunt for Red October, The (1990)                                               0.977185
#         In & Out (1997)                                                                0.463014
#         In the Line of Fire (1993)                                                     0.201735
#         Independence Day (ID4) (1996)                                                  1.243770
#         Indiana Jones and the Last Crusade (1989)                                      1.750535
#         Interview with the Vampire (1994)                                              1.193477
#         It's a Wonderful Life (1946)                                                   1.114232
#         Jackie Chan's First Strike (1996)                                              1.255621
#         James and the Giant Peach (1996)                                               1.124513
#         Jaws (1975)                                                                    1.327297
#         Jerry Maguire (1996)                                                           0.194941
#         Jurassic Park (1993)                                                           0.860614
#         Killing Fields, The (1984)                                                    -0.085612
#         Kingpin (1996)                                                                 0.958217
#         L.A. Confidential (1997)                                                       1.595323
#         Last of the Mohicans, The (1992)                                               0.360961
#         Lawrence of Arabia (1962)                                                      1.036151
#         Leaving Las Vegas (1995)                                                       0.344599
#         Liar Liar (1997)                                                               0.751459
#         Like Water For Chocolate (Como agua para chocolate) (1992)                     0.738691
#         Lion King, The (1994)                                                          1.178032
#         Lone Star (1996)                                                               0.593966
#         Long Kiss Goodnight, The (1996)                                                0.730454
#         Lost World: Jurassic Park, The (1997)                                          0.617888
#         M*A*S*H (1970)                                                                 0.694308
#         Magnificent Seven, The (1954)                                                  0.925512
#         Maltese Falcon, The (1941)                                                     0.708985
#         Manchurian Candidate, The (1962)                                              -0.100579
#         Mars Attacks! (1996)                                                           0.197850
#         Mary Poppins (1964)                                                            0.674462
#         Mask, The (1994)                                                               1.073120
#         Maverick (1994)                                                                0.396175
#         Men in Black (1997)                                                            1.012558
#         Mighty Aphrodite (1995)                                                        0.650742
#         Mission: Impossible (1996)                                                     0.737658
#         Monty Python and the Holy Grail (1974)                                         1.035135
#         Monty Python's Life of Brian (1979)                                            1.030806
#         Mr. Holland's Opus (1995)                                                      0.102832
#         Mrs. Doubtfire (1993)                                                          0.420022
#         Much Ado About Nothing (1993)                                                 -0.010652
#         Multiplicity (1996)                                                           -0.043897
#         Murder at 1600 (1997)                                                         -0.323890
#         My Best Friend's Wedding (1997)                                                0.544283
#         My Fair Lady (1964)                                                           -0.098805
#         Mystery Science Theater 3000: The Movie (1996)                                 1.509047
#         Natural Born Killers (1994)                                                    0.268845
#         Net, The (1995)                                                                0.948764
#         Nightmare Before Christmas, The (1993)                                         0.549392
#         Nikita (La Femme Nikita) (1990)                                               -0.201641
#         North by Northwest (1959)                                                      0.885679
#         Nutty Professor, The (1996)                                                    1.012428
#         One Flew Over the Cuckoo's Nest (1975)                                         0.394143
#         Patton (1970)                                                                  0.897599
#         People vs. Larry Flynt, The (1996)                                             0.567022
#         Phenomenon (1996)                                                             -0.111796
#         Philadelphia (1993)                                                            0.336095
#         Piano, The (1993)                                                              0.356501
#         Pink Floyd - The Wall (1982)                                                   0.287813
#         Platoon (1986)                                                                 1.031651
#         Postino, Il (1994)                                                             0.429850
#         Pretty Woman (1990)                                                            0.609717
#         Primal Fear (1996)                                                             0.614312
#         Princess Bride, The (1987)                                                     1.298554
#         Professional, The (1994)                                                       0.703223
#         Psycho (1960)                                                                  0.323624
#         Pulp Fiction (1994)                                                           -0.107838
#         Quiz Show (1994)                                                               0.604187
#         Raiders of the Lost Ark (1981)                                                 2.680586
#         Raising Arizona (1987)                                                         0.382315
#         Ransom (1996)                                                                 -0.175922
#         Real Genius (1985)                                                            -0.480527
#         Rear Window (1954)                                                             0.343743
#         Remains of the Day, The (1993)                                                -0.560337
#         Reservoir Dogs (1992)                                                         -0.090479
#         Return of the Jedi (1983)                                                      3.362779
#         Right Stuff, The (1983)                                                        1.044537
#         River Wild, The (1994)                                                         0.380748
#         Rock, The (1996)                                                               0.239686
#         Room with a View, A (1986)                                                     0.535782
#         Rumble in the Bronx (1995)                                                     0.110165
#         Sabrina (1995)                                                                 0.762194
#         Saint, The (1997)                                                              0.529201
#         Schindler's List (1993)                                                        0.504663
#         Scream (1996)                                                                  0.673239
#         Searching for Bobby Fischer (1993)                                             1.111000
#         Secrets & Lies (1996)                                                          0.905150
#         Sense and Sensibility (1995)                                                   0.451863
#         Seven (Se7en) (1995)                                                           0.030482
#         Shawshank Redemption, The (1994)                                               0.874929
#         Shine (1996)                                                                   0.943997
#         Shining, The (1980)                                                            0.196825
#         Silence of the Lambs, The (1991)                                               0.197439
#         Singin' in the Rain (1952)                                                     1.282474
#         Sleepers (1996)                                                                0.441851
#         Sleepless in Seattle (1993)                                                    0.895013
#         Sling Blade (1996)                                                             0.878889
#         Sneakers (1992)                                                                0.945648
#         Snow White and the Seven Dwarfs (1937)                                         1.351730
#         Some Like It Hot (1959)                                                        0.621467
#         Sound of Music, The (1965)                                                     0.435866
#         Speed (1994)                                                                   0.376139
#         Stand by Me (1986)                                                             0.418840
#         Star Trek III: The Search for Spock (1984)                                     1.009876
#         Star Trek IV: The Voyage Home (1986)                                           0.784798
#         Star Trek VI: The Undiscovered Country (1991)                                  0.431279
#         Star Trek: First Contact (1996)                                                1.277646
#         Star Trek: Generations (1994)                                                  1.271598
#         Star Trek: The Motion Picture (1979)                                           1.303271
#         Star Trek: The Wrath of Khan (1982)                                            1.411029
#         Star Wars (1977)                                                               5.000000
#         Stargate (1994)                                                                0.398749
#         Starship Troopers (1997)                                                       0.316649
#         Sting, The (1973)                                                              1.837692
#         Swingers (1996)                                                                1.446551
#         Taxi Driver (1976)                                                             0.149316
#         Terminator 2: Judgment Day (1991)                                              1.037994
#         Terminator, The (1984)                                                         1.311273
#         That Thing You Do! (1996)                                                      0.950990
#         This Is Spinal Tap (1984)                                                     -0.403978
#         Time to Kill, A (1996)                                                        -0.213951
#         Tin Cup (1996)                                                                 0.586399
#         Titanic (1997)                                                                 0.409642
#         To Kill a Mockingbird (1962)                                                   0.645060
#         Tomorrow Never Dies (1997)                                                     1.276052
#         Top Gun (1986)                                                                 0.874076
#         Toy Story (1995)                                                               0.900099
#         Trainspotting (1996)                                                           0.107518
#         True Lies (1994)                                                               0.991530
#         Truth About Cats & Dogs, The (1996)                                            0.729107
#         Twelve Monkeys (1995)                                                          0.777652
#         Twister (1996)                                                                 0.191160
#         Under Siege (1992)                                                             0.133519
#         Unforgiven (1992)                                                              0.275296
#         Usual Suspects, The (1995)                                                     1.055373
#         Vertigo (1958)                                                                 0.403177
#         Volcano (1997)                                                                 0.229737
#         What's Eating Gilbert Grape (1993)                                            -0.302473
#         When Harry Met Sally... (1989)                                                 0.599245
#         While You Were Sleeping (1995)                                                 0.780594
#         Willy Wonka and the Chocolate Factory (1971)                                   1.109510
#         Wizard of Oz, The (1939)                                                       1.331676
#         Wrong Trousers, The (1993)                                                     1.081020
#         Young Frankenstein (1974)                                                      0.962943
# Name: (rating, Star Wars (1977)), dtype: float64
#
# sorting..
#
# (rating, Empire Strikes Back, The (1980))                       5.000000
# (rating, Star Wars (1977))                                      5.000000
# (rating, Empire Strikes Back, The (1980))                       3.741763
# (rating, Star Wars (1977))                                      3.741763
# (rating, Return of the Jedi (1983))                             3.606146
# (rating, Return of the Jedi (1983))                             3.362779
# (rating, Raiders of the Lost Ark (1981))                        2.693297
# (rating, Raiders of the Lost Ark (1981))                        2.680586
# (rating, Austin Powers: International Man of Mystery (1997))    1.887164
# (rating, Sting, The (1973))                                     1.837692
# dtype: float64

# %% [markdown]
# For i in range 0 through the number of ratings that I have in `myRatings`, I am going to add up similar movies to the ones that I rated. So, I'm going to take that `corrMatrix` DataFrame, that magical one that has all of the movie similarities, and I am going to create a correlation matrix with `myRatings`, drop any missing values, and then I am going to scale that resulting correlation score by how well I rated that movie.
#
# So, the idea here is I'm going to go through all the similarities for The Empire Strikes Back, for example, and I will scale it all by 5, because I really liked The Empire Strikes Back. But, when I go through and get the similarities for Gone with the Wind, I'm only going to scale those by 1, because I did not like Gone with the Wind. So, this will give more strength to movies that are similar to movies that I liked, and less strength to movies that are similar to movies that I did not like, okay? So, I just go through and build up this list of similarity candidates, recommendation candidates if you will, sort the results and print them out. Let's see what we get above

# %% [markdown]
# Hey, those don't look too bad, right? So, obviously The `Empire Strikes Back (1980)` and `Star Wars (1977)` come out on top, because I like those movies explicitly, I already watched them and rated them. But, bubbling up to the top of the list is `Return of the Jedi (1983)`, which we would expect and `Raiders of the Lost Ark (1981)`.
#
# Let's start to refine these results a little bit more. We're seeing that we're getting duplicate values back. If we have a movie that was similar to more than one movie that I rated, it will come back more than once in the results, so we want to combine those together. If I do in fact have the same movie, maybe that should get added up together into a combined, stronger recommendation score. Return of the Jedi, for example, was similar to both Star Wars and The Empire Strikes Back. How would we do that?

# %% [markdown]
# ## Using the groupby command to combine rows

# %% [markdown]
# We'll go ahead and explore that. We're going to use the groupby command again to group together all of the rows that are for the same movie. Next, we will sum up their correlation score and look at the results:

# %%
simCandidates = simCandidates.groupby(simCandidates.index).sum()
simCandidates.sort_values(inplace=True,ascending=False)
simCandidates.head(10)
# Out:
# (rating, Empire Strikes Back, The (1980))              8.877450
# (rating, Star Wars (1977))                             8.870971
# (rating, Return of the Jedi (1983))                    7.178172
# (rating, Raiders of the Lost Ark (1981))               5.519700
# (rating, Indiana Jones and the Last Crusade (1989))    3.488028
# (rating, Bridge on the River Kwai, The (1957))         3.366616
# (rating, Back to the Future (1985))                    3.357941
# (rating, Sting, The (1973))                            3.329843
# (rating, Cinderella (1950))                            3.245412
# (rating, Field of Dreams (1989))                       3.222311
# dtype: float64

# %% [markdown]
# Hey, this is looking really good!
#
# So `Return of the Jedi (1983)` comes out way on top, as it should, with a score of 7, `Raiders of the Lost Ark (1981)` a close second at 5, and then we start to get to `Indiana Jones and the Last Crusade (1989)`, and some more movies, `The Bridge on the River Kwai (1957)`, `Back to the Future (1985)`,`The Sting (1973)`. These are all movies that I would actually enjoy watching! You know, I actually do like old-school Disney movies too, so `Cinderella (1950)` isn't as crazy as it might seem.
#
# The last thing we need to do is filter out the movies that I've already rated, because it doesn't make sense to recommend movies you've already seen.

# %% [markdown]
# ## Removing entries with the drop command

# %% [markdown]
# So, I can quickly drop any rows that happen to be in my original ratings series using the following code:

# %%
filteredSims = simCandidates.drop(myRatings.index)
filteredSims.head(10)
# Out:
# (rating, Return of the Jedi (1983))                    7.178172
# (rating, Raiders of the Lost Ark (1981))               5.519700
# (rating, Indiana Jones and the Last Crusade (1989))    3.488028
# (rating, Bridge on the River Kwai, The (1957))         3.366616
# (rating, Back to the Future (1985))                    3.357941
# (rating, Sting, The (1973))                            3.329843
# (rating, Cinderella (1950))                            3.245412
# (rating, Field of Dreams (1989))                       3.222311
# (rating, Wizard of Oz, The (1939))                     3.200268
# (rating, Dumbo (1941))                                 2.981645
# dtype: float64

# %% [markdown]
# And there we have it! `Return of the Jedi (1983)`, `Raiders of the Lost Ark (1981)`, `Indiana Jones` and `the Last Crusade (1989)`, all the top results for my fictitious user, and they all make sense. I'm seeing a few family-friendly films, you know, `Cinderella (1950)`, `The Wizard of Oz (1939)`, `Dumbo (1941)`, creeping in, probably based on the presence of Gone with the Wind in there, even though it was weighted downward it's still in there, and still being counted. And, there we have our results, so. There you have it! Pretty cool!
#
# We have actually generated recommendations for a given user and we could do that for any user in our entire DataFrame. So, go ahead and play with that if you want to. I also want to talk about how you can actually get your hands dirty a little bit more, and play with these results; try to improve upon them.
#
# There's a bit of an art to this, you know, you need to keep iterating and trying different ideas and different techniques until you get better and better results, and you can do this pretty much forever. I mean, I made a whole career out of it. So, I don't expect you to spend the next, you know, 10 years trying to refine this like I did, but there are some simple things you can do, so let's talk about that.
